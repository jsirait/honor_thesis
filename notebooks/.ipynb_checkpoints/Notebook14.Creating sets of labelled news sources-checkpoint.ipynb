# %% [markdown]
# # Creating sets of labelled news sources
#
# I will create labelled news sources based on reliability, political leaning, media type, and geographical location.

# %%
import json
import csv
import os

# %%
import tldextract

# %%
from collections import Counter, defaultdict

# %% [markdown]
# ## Reliability
#
# Using News Guard

# %%
newsguard = json.load(open("new_newsguard_rated.json", "r", encoding="utf-8"))

# %%
reliability = dict()
for ns,rate in newsguard:
    if rate <= 60.0:
        reliability[ns] = "unreliable"
    else:
        reliability[ns] = "reliable"

# %%
json.dump(reliability, open("reliability.json", "w", encoding="utf-8"))

# %% [markdown]
# ## Political Leaning
#
# Using Media Bias Fact Check

# %%
pd1 = os.path.split(os.getcwd())[0]
mbfc_path = os.path.join(pd1, "data/mbfc")

# %%
lf = json.load(open(os.path.join(mbfc_path, "mbfc_left.json")))
lc = json.load(open(os.path.join(mbfc_path, "mbfc_leftcenter.json")))

rh = json.load(open(os.path.join(mbfc_path, "mbfc_right.json")))
rc = json.load(open(os.path.join(mbfc_path, "mbfc_right-center.json")))

# %%
ns_fixed_ = json.load(open("ns_fixed_.json", "r", encoding="utf-8"))

# %%
left = list(set(ns_fixed_) & (set([k[1] for k in lf]) | set([k[1] for k in lc])))
len(left)
# Out:
# 158

# %%
right = (set(ns_fixed_) & (set([k[1] for k in rh]) | set([k[1] for k in rc])))
len(right)
# Out:
# 84

# %%
political_leaning = dict()

for l in left:
    political_leaning[l] = "left"

for r in right:
    political_leaning[r] = "right"

# %%
json.dump(political_leaning, open("political_leaning.json", "w", encoding="utf-8"))

# %% [markdown]
# ## Media Type

# %%
muckrack_path = os.path.join(pd1, "data/muckrack")

# %%
new_muckrack = json.load(open(os.path.join(muckrack_path, "all_new_muckrack.json")))
len(new_muckrack)
# Out:
# 594687

# %%
old_muckrack = json.load(open(os.path.join(muckrack_path, "all_old_muckrack.json")))

# %%
# let us clean both new and old muckrack
clean_new_muckrack = dict()

for nsm in new_muckrack:
    extracted = tldextract.extract(nsm)
    subdomain, domain, suffix = extracted
    # add both versions of domain.suffix and subdomain.domain.suffix
    full = ""
    # with subdomain
    if len(subdomain) > 0:
        #print(f"{subdomain}.{domain}.{suffix}")
        full = f"{subdomain}.{domain}.{suffix}"
        if len(full) > 0:
            clean_new_muckrack[full.replace("www.","").strip('/')] = new_muckrack[nsm]
    # without subdomain
    full = f"{domain}.{suffix}"
    if len(full) > 0:
        clean_new_muckrack[full.replace("www.","").strip('/')] = new_muckrack[nsm]
len(clean_new_muckrack)
# Out:
# 450591

# %%
clean_new_muckrack["tribunnews.com"]
# Out:
# [{'source_name': 'Banjarmasin Post',
#   'location': 'Banjarmasin, Kalimantan, ID',
#   'media_type': 'Newspaper'}]

# %%
len(set(clean_new_muckrack.keys()) & set(ns_fixed_))
# Out:
# 2464

# %%
len(ns_fixed_)
# Out:
# 2639

# %% [markdown]
# ### According to new muck rack

# %%
media_type = dict()

for k in ns_fixed_:
    media_type[k] = clean_new_muckrack[k][0]['media_type'] if k in clean_new_muckrack else ''

# %%
media_type
# Out:
# {'crimeonline.com': 'Podcast',
#  'cornell.edu': 'Podcast',
#  'wealthsimple.com': '',
#  'newscientist.com': 'Podcast',
#  'insider.com': 'Online/Digital',
#  'kcci.com': 'Television',
#  'hackernoon.com': '',
#  'thebetterindia.com': 'Online/Digital',
#  'wcpo.com': 'Podcast',
#  'theculturetrip.com': '',
#  'king5.com': 'Television',
#  'runnersworld.com': 'Magazine',
#  'crimereads.com': '',
#  'businessinsider.com': 'Online/Digital',
#  'futurism.com': 'Online/Digital',
#  'moneymorning.com': 'Online/Digital',
#  'applytojob.com': '',
#  'montgomeryadvertiser.com': 'Newspaper',
#  'mlbtraderumors.com': 'Online/Digital',
#  'gizchina.com': '',
#  'journaltimes.com': 'Newspaper',
#  'thegrio.com': 'Online/Digital',
#  'sfgate.com': 'Newsletter (Digital)',
#  'motortrend.com': 'Magazine',
#  'thehindu.com': '',
#  'uber.com': 'Blog',
#  'lasvegassun.com': 'Newspaper',
#  'metro.co.uk': 'Newsletter (Digital)',
#  'musicradar.com': 'Magazine',
#  'californiaglobe.com': '',
#  'nsf.gov': 'Podcast',
#  'cnn.com': 'Newsletter (Digital)',
#  'americanprogress.org': 'Online/Digital',
#  '9to5mac.com': 'Podcast',
#  'timesnownews.com': 'Television',
#  'americamagazine.org': 'Magazine',
#  'ama-assn.org': 'Online/Digital',
#  'houstonpress.com': 'Newspaper',
#  'colorado.edu': 'Podcast',
#  'bostonherald.com': 'Newspaper',
#  'eurogamer.net': 'Online/Digital',
#  'kansascity.com': 'Podcast',
#  'reviewjournal.com': 'Podcast',
#  'businessinsider.com.au': 'Online/Digital',
#  'wired.co.uk': '',
#  'rt.com': '',
#  'theweek.com': 'Magazine',
#  'pasadenastarnews.com': '',
#  'elsevier.com': 'Journal',
#  'vancouverisland.ctvnews.ca': 'Television',
#  'pastemagazine.com': '',
#  'looper.com': 'Online/Digital',
#  'cbs42.com': 'Television',
#  'waff.com': 'Television',
#  'techradar.com': 'Magazine',
#  'telegraph.co.uk': 'Podcast',
#  'sagepub.com': 'Magazine',
#  'newrepublic.com': 'Magazine',
#  'lesechos.fr': 'Online/Digital',
#  'toledoblade.com': 'Newspaper',
#  'renews.biz': 'Newsletter (Print)',
#  'breitbart.com': 'Online/Digital',
#  'wiktionary.org': '',
#  'sunjournal.com': 'Newspaper',
#  'outkick.com': 'Radio Program',
#  'nbc4i.com': 'Television',
#  'nerdwallet.com': 'Podcast',
#  'utexas.edu': 'Podcast',
#  'lohud.com': 'Newspaper',
#  'tbsnews.net': '',
#  'wkrn.com': 'Television',
#  'billingsgazette.com': 'Newspaper',
#  'staradvertiser.com': 'Newspaper',
#  'thesouthafrican.com': 'Online/Digital',
#  'engadget.com': 'Blog',
#  'mississippitoday.org': 'Podcast',
#  'techcrunch.com': 'Podcast',
#  'si.edu': 'Online/Digital',
#  'coventrytelegraph.net': '',
#  'ky3.com': 'Television',
#  'breakingdefense.com': '',
#  'wlky.com': 'Television',
#  'thoughtco.com': 'Online/Digital',
#  'msn.com': 'Online/Digital',
#  'business.site': 'Podcast',
#  'simplywall.st': '',
#  'freightwaves.com': 'Online/Digital',
#  'kusi.com': 'Podcast',
#  'pcgamesn.com': '',
#  'bloombergquint.com': 'Online/Digital',
#  'fox10phoenix.com': 'Television',
#  'orlandosentinel.com': 'Podcast',
#  'wlos.com': 'Television',
#  'mprnews.org': 'Podcast',
#  'fox19.com': 'Television',
#  'foodnetwork.com': '',
#  'wpcomstaging.com': 'Podcast',
#  'swarajyamag.com': 'Magazine',
#  'deccanchronicle.com': 'Newspaper',
#  'motorauthority.com': 'Online/Digital',
#  'cntraveler.com': 'Magazine',
#  'autodesk.com': '',
#  '20minutes.fr': 'Newspaper',
#  'psychiatryonline.org': 'Online/Digital',
#  'fox6now.com': 'Television',
#  'wmnf.org': 'Radio',
#  'dailystar.co.uk': 'Newspaper',
#  'silive.com': 'Newspaper',
#  'birminghammail.co.uk': 'Podcast',
#  'americanmilitarynews.com': 'Online/Digital',
#  'unity.com': '',
#  'digitalmusicnews.com': 'Online/Digital',
#  'industryweek.com': 'Magazine',
#  'bfmtv.com': 'Podcast',
#  'winteriscoming.net': '',
#  'mcall.com': 'Podcast',
#  'letterboxd.com': 'Podcast',
#  'insideclimatenews.org': 'Online/Digital',
#  'arabianbusiness.com': 'Online/Digital',
#  'cbs8.com': 'Television',
#  'hollywoodreporter.com': 'Podcast',
#  'fox40.com': 'Television',
#  'metalsucks.net': 'Podcast',
#  'solarpowerworldonline.com': 'Podcast',
#  'note.com': 'Podcast',
#  'hyperallergic.com': '',
#  'kctv5.com': 'Television Program',
#  'visualcapitalist.com': 'Online/Digital',
#  'portswigger.net': 'Online/Digital',
#  'physicsworld.com': 'Magazine',
#  'scotsman.com': 'Newsletter (Digital)',
#  'wbrc.com': 'Television',
#  'dallasnews.com': 'Newspaper',
#  'ktvz.com': 'Television',
#  'metrotimes.com': 'Newspaper',
#  'handelsblatt.com': '',
#  'ucalgary.ca': '',
#  'lawfareblog.com': 'Podcast',
#  'elconfidencial.com': 'Online/Digital',
#  'courtlistener.com': 'Podcast',
#  'pcgamer.com': 'Magazine',
#  'quantamagazine.org': 'Podcast',
#  'virginiamercury.com': 'Online/Digital',
#  'ahajournals.org': '',
#  'katu.com': 'Television',
#  'local10.com': 'Television',
#  'theblaze.com': 'Online/Digital',
#  'whas11.com': 'Television',
#  'radio.com': 'Podcast',
#  'wallofsoundau.com': 'Podcast',
#  'indiatvnews.com': 'Television',
#  'listennotes.com': 'Podcast',
#  'okcfox.com': 'Television',
#  'iol.co.za': 'Newspaper',
#  'thelogicalindian.com': 'Newswire/News Agency',
#  'consortiumnews.com': '',
#  'nationalgeographic.com': 'Podcast',
#  'elpais.com': '',
#  'wtop.com': 'Radio',
#  'foxsports.com.au': '',
#  'vnexpress.net': 'Podcast',
#  'prospectmagazine.co.uk': 'Magazine',
#  'theathletic.com': 'Podcast',
#  'defenseone.com': 'Online/Digital',
#  'empireonline.com': '',
#  'keengamer.com': '',
#  'edweek.org': '',
#  'distrokid.com': 'Podcast',
#  'leparisien.fr': 'Newspaper',
#  'driving.ca': '',
#  'windows.com': '',
#  'tallahassee.com': 'Newspaper',
#  'ens-newswire.com': 'Newswire/News Agency',
#  'unlimitedhangout.com': '',
#  'fox59.com': 'Television Program',
#  'london.ctvnews.ca': 'Television',
#  'thenews.com.pk': 'Newspaper',
#  'dallasobserver.com': 'Newspaper',
#  'bbc.com': '',
#  'grunge.com': '',
#  'thisismoney.co.uk': 'Online/Digital',
#  'techpowerup.com': 'Online/Digital',
#  'inc.com': 'Podcast',
#  'scitation.org': '',
#  'nasa.gov': 'Podcast',
#  'kark.com': 'Television',
#  'inthesetimes.com': 'Magazine',
#  'liberation.fr': 'Newspaper',
#  'saskatoon.ctvnews.ca': 'Television',
#  'minnesotareformer.com': '',
#  'fortressofsolitude.co.za': '',
#  'mmafighting.com': 'Podcast',
#  'ladbible.com': 'Online/Digital',
#  'hotair.com': '',
#  'lifesitenews.com': 'Online/Digital',
#  'naturalnews.com': 'Podcast',
#  'out.com': 'Magazine',
#  'nwaonline.com': 'Newspaper',
#  'repubblica.it': 'Podcast',
#  'justthenews.com': '',
#  'gobankingrates.com': 'Online/Digital',
#  'dcist.com': 'Blog',
#  'nairametrics.com': 'Online/Digital',
#  'thediplomat.com': 'Magazine',
#  'hbomax.com': 'Podcast',
#  'thoughtcatalog.com': 'Online/Digital',
#  'electrek.co': 'Podcast',
#  'ucsusa.org': 'Blog',
#  'gcs-web.com': '',
#  'ottawacitizen.com': 'Newspaper',
#  'cleanenergywire.org': 'Online/Digital',
#  'usf.edu': 'Podcast',
#  'coloradopolitics.com': 'Online/Digital',
#  'thestate.com': 'Newspaper',
#  'wolfstreet.com': '',
#  'foxnews.com': 'Podcast',
#  'progressive.org': 'Magazine',
#  'latestly.com': 'Online/Digital',
#  'globenewswire.com': '',
#  'thedispatch.com': 'Podcast',
#  'pca.st': 'Podcast',
#  'arabnews.com': 'Newspaper',
#  'mediamatters.org': 'Online/Digital',
#  'tim.blog': 'Podcast',
#  'essence.com': 'Online/Digital',
#  'fastcompany.com': 'Podcast',
#  'flipboard.com': '',
#  'citynews1130.com': '',
#  'crowdfundinsider.com': '',
#  'wspa.com': 'Television',
#  'ieee.org': 'Magazine',
#  'flightradar24.com': 'Podcast',
#  '5newsonline.com': 'Television',
#  'fxempire.com': '',
#  'sandiegouniontribune.com': 'Newspaper',
#  'goodhousekeeping.com': 'Podcast',
#  'palmbeachpost.com': '',
#  'statnews.com': 'Podcast',
#  'pe.com': 'Newspaper',
#  'sciencedirect.com': 'Journal',
#  'darkreading.com': 'Online/Digital',
#  'fivethirtyeight.com': '',
#  'wkbw.com': 'Television',
#  'bookriot.com': 'Podcast',
#  'gsmarena.com': 'Online/Digital',
#  'abc.net.au': 'Podcast',
#  'aminoapps.com': 'Podcast',
#  'gurufocus.com': 'Online/Digital',
#  'arkansasonline.com': 'Podcast',
#  'drivetribe.com': 'Online/Digital',
#  'mdr.de': 'Podcast',
#  'capitalgazette.com': 'Newspaper',
#  'notebookcheck.net': 'Online/Digital',
#  'workers.org': 'Podcast',
#  'cbsaustin.com': 'Television',
#  'junkee.com': 'Online/Digital',
#  'harpers.org': 'Podcast',
#  'saltwire.com': 'Newspaper',
#  'manofmany.com': '',
#  'pocketgamer.com': 'Online/Digital',
#  'blu-ray.com': '',
#  'euractiv.com': 'Podcast',
#  'canadiandimension.com': 'Magazine',
#  'thesource.com': 'Magazine',
#  'thenextweb.com': 'Online/Digital',
#  'torquenews.com': 'Blog',
#  'xsnoize.com': 'Online/Digital',
#  'natlawreview.com': 'Online/Digital',
#  'asianews.it': '',
#  'everythinglubbock.com': 'Television',
#  'heraldsun.com.au': 'Podcast',
#  'wwlp.com': 'Television',
#  'zycrypto.com': '',
#  'fox35orlando.com': 'Television Program',
#  'umn.edu': '',
#  'greentechmedia.com': 'Podcast',
#  'bps.org.uk': 'Magazine',
#  'eenews.net': 'Online/Digital',
#  'dailyvoice.com': 'Online/Digital',
#  'bizjournals.com': 'Podcast',
#  'dispatch.com': 'Podcast',
#  'theday.com': 'Newspaper',
#  'abc7.com': 'Television',
#  'theafricareport.com': 'Magazine',
#  'wfsb.com': 'Television',
#  'carbuzz.com': '',
#  'hellomagazine.com': 'Magazine',
#  'osu.edu': 'Online/Digital',
#  'zazzle.com': 'Podcast',
#  'nsw.gov.au': 'Podcast',
#  'antiwar.com': 'Online/Digital',
#  'tripadvisor.com': 'Online/Digital',
#  'mit.edu': '',
#  'newson6.com': 'Television',
#  'inforum.com': 'Podcast',
#  'rochester.edu': 'Podcast',
#  'firstcoastnews.com': 'Television',
#  'bc.ctvnews.ca': '',
#  'rbth.com': '',
#  'raspberrypi.org': 'Magazine',
#  'delish.com': 'Online/Digital',
#  'thecurrencyanalytics.com': '',
#  'spectator.us': '',
#  'yougov.co.uk': 'Online/Digital',
#  'elitedaily.com': 'Online/Digital',
#  'pressprogress.ca': '',
#  'caranddriver.com': 'Magazine',
#  'pinkvilla.com': 'Online/Digital',
#  'uw.edu': '',
#  'codepen.io': 'Podcast',
#  '9to5google.com': 'Podcast',
#  'utah.gov': 'Podcast',
#  'postandcourier.com': 'Newspaper',
#  'wsmv.com': 'Television',
#  'cmu.edu': 'Podcast',
#  'staples.com': '',
#  'insiderfinancial.com': 'Podcast',
#  '10tv.com': 'Television',
#  'thetruthaboutguns.com': 'Blog',
#  'wric.com': 'Television',
#  'redstate.com': 'Blog',
#  'mymodernmet.com': 'Online/Digital',
#  'ct.gov': 'Podcast',
#  'jacobinmag.com': '',
#  'arstechnica.com': 'Online/Digital',
#  'wkyc.com': 'Television',
#  'scientificamerican.com': 'Podcast',
#  'businesstimes.com.sg': 'Newspaper',
#  'columbia.edu': 'Podcast',
#  'twinfinite.net': 'Online/Digital',
#  'list-manage.com': '',
#  'mylondon.news': 'Online/Digital',
#  'cp24.com': 'Newspaper',
#  'nationalinterest.org': 'Magazine',
#  'detroitnews.com': 'Podcast',
#  'edmontonjournal.com': 'Newspaper',
#  'thenationalpulse.com': 'Online/Digital',
#  'techstartups.com': 'Online/Digital',
#  'neocities.org': 'Podcast',
#  'army.mil': 'Podcast',
#  'player.fm': 'Podcast',
#  'westernstandardonline.com': 'Online/Digital',
#  'tmz.com': 'Newsletter (Digital)',
#  'reneweconomy.com.au': 'Podcast',
#  'brisbanetimes.com.au': 'Newspaper',
#  'rockpapershotgun.com': 'Podcast',
#  'adweek.com': 'Podcast',
#  'ifixit.com': '',
#  'japan-forward.com': 'Online/Digital',
#  'coastreporter.net': '',
#  'jdsupra.com': '',
#  'armradio.am': 'Radio',
#  'thebiglead.com': 'Blog',
#  'freakonomics.com': 'Podcast',
#  'wfpk.org': '',
#  'patheos.com': 'Podcast',
#  'dronedj.com': '',
#  'libsyn.com': 'Podcast',
#  'buzzsprout.com': 'Podcast',
#  'knowyourmeme.com': '',
#  'sciencetimes.com': '',
#  '13abc.com': 'Television',
#  'thescore.com': 'Online/Digital',
#  'ktxs.com': 'Television',
#  'crosscut.com': '',
#  'gulfnews.com': 'Newspaper',
#  'kmov.com': 'Podcast',
#  'dailymotion.com': 'Podcast',
#  'todayonline.com': 'Newspaper',
#  'calgary.ctvnews.ca': 'Television',
#  'uwaterloo.ca': 'Podcast',
#  'hongkongfp.com': 'Online/Digital',
#  'businessinsider.co.za': '',
#  'pharmaceutical-technology.com': 'Magazine',
#  'goal.com': 'Online/Digital',
#  'telegram.com': 'Podcast',
#  'khon2.com': 'Television',
#  'gothamist.com': 'Online/Digital',
#  'inverse.com': 'Podcast',
#  'fox8.com': 'Television',
#  'judicialwatch.org': 'Online/Digital',
#  'chtbl.com': 'Podcast',
#  'prweb.com': '',
#  'phoenixnewtimes.com': 'Newspaper',
#  'democratandchronicle.com': 'Newspaper',
#  'artofmanliness.com': 'Online/Digital',
#  'dawn.com': 'Online/Digital',
#  'wallstreet-online.de': 'Podcast',
#  'unl.edu': 'Podcast',
#  'studyfinds.org': '',
#  'observador.pt': 'Podcast',
#  'northjersey.com': 'Newspaper',
#  'thegrayzone.com': '',
#  'truthout.org': 'Online/Digital',
#  'iphoneincanada.ca': '',
#  'ktvu.com': 'Television',
#  'marketbeat.com': '',
#  'kgw.com': 'Television',
#  'mercurynews.com': 'Newspaper',
#  'nsnews.com': 'Newspaper',
#  'gitconnected.com': '',
#  'starwars.com': 'Online/Digital',
#  'thelondoneconomic.com': 'Online/Digital',
#  'medicalnewstoday.com': 'Online/Digital',
#  'cbn.com': 'Podcast',
#  'oregonstate.edu': 'Podcast',
#  'biologicaldiversity.org': 'Newsletter (Digital)',
#  'republicworld.com': 'Television',
#  'technologyreview.com': 'Podcast',
#  'popularmechanics.com': 'Magazine',
#  'courant.com': 'Newspaper',
#  'komonews.com': 'Podcast',
#  'hypebeast.com': 'Online/Digital',
#  'greencarreports.com': 'Online/Digital',
#  'newslaundry.com': 'Podcast',
#  'entrepreneur.com': 'Podcast',
#  'btcmanager.com': 'Online/Digital',
#  'shine.cn': '',
#  'gq-magazine.co.uk': 'Magazine',
#  'sciencealert.com': '',
#  'thecut.com': '',
#  'sun-sentinel.com': 'Newspaper',
#  'rfi.fr': 'Podcast',
#  'lcsun-news.com': 'Newspaper',
#  'nbcbayarea.com': '',
#  'guitarcenter.com': 'Online/Digital',
#  'focus.de': '',
#  'angel.co': 'Podcast',
#  'prnewswire.co.uk': '',
#  'gatech.edu': '',
#  'elmundo.es': 'Online/Digital',
#  'qz.com': 'Newsletter (Digital)',
#  'dhakatribune.com': 'Newspaper',
#  'westerndigital.com': '',
#  'hubspot.com': 'Blog',
#  'newcannabisventures.com': 'Online/Digital',
#  'nhl.com': 'Podcast',
#  'kfor.com': 'Television',
#  'examinerlive.co.uk': 'Online/Digital',
#  'rochesterfirst.com': 'Television',
#  'beincrypto.com': 'Online/Digital',
#  'milenio.com': 'Podcast',
#  'force.com': '',
#  'supchina.com': 'Podcast',
#  'govexec.com': 'Magazine',
#  'pennlive.com': 'Podcast',
#  'marketscreener.com': '',
#  'kenoshanews.com': 'Newspaper',
#  'wccftech.com': 'Magazine',
#  'sapo.pt': 'Podcast',
#  'ghacks.net': 'Online/Digital',
#  'vanguardngr.com': '',
#  'franceinter.fr': 'Podcast',
#  'jacksonville.com': '',
#  'reuters.com': 'Newswire/News Agency',
#  'pymnts.com': 'Online/Digital',
#  'uga.edu': 'Podcast',
#  'in.gov': 'Podcast',
#  'montrealgazette.com': 'Newspaper',
#  'realclearinvestigations.com': '',
#  'i24news.tv': '',
#  'econotimes.com': 'Online/Digital',
#  'orlandoweekly.com': 'Newspaper',
#  'africanews.com': 'Online/Digital',
#  'buzzfeednews.com': 'Online/Digital',
#  'foreignaffairs.com': '',
#  'dailykos.com': 'Podcast',
#  'cnnphilippines.com': 'Television',
#  'mindbodygreen.com': 'Online/Digital',
#  'cnbc.com': 'Podcast',
#  'cpr.org': 'Podcast',
#  'palestinechronicle.com': '',
#  'wkrg.com': 'Television',
#  'tvanouvelles.ca': 'Television',
#  'latimes.com': 'Newspaper',
#  'katc.com': 'Television',
#  'kpbs.org': 'Podcast',
#  'ktsm.com': 'Television',
#  'aphapublications.org': 'Journal',
#  'distractify.com': 'Online/Digital',
#  'hearthis.at': 'Podcast',
#  'thethings.com': 'Online/Digital',
#  'kvia.com': 'Television',
#  'asu.edu': 'Podcast',
#  'ap.org': '',
#  'uchicago.edu': '',
#  'podomatic.com': 'Podcast',
#  'kcra.com': 'Television',
#  'goodmorningamerica.com': 'Television Program',
#  'moneycontrol.com': 'Podcast',
#  'fox2now.com': 'Television',
#  'digitaltrends.com': '',
#  'abcnews4.com': 'Television',
#  'vaticannews.va': 'Podcast',
#  'dr.dk': 'Podcast',
#  'nysmusic.com': '',
#  'artnews.com': 'Magazine',
#  'tulsaworld.com': 'Newspaper',
#  'townandcountrymag.com': 'Magazine',
#  'afr.com': 'Magazine',
#  'areomagazine.com': 'Magazine',
#  'eonline.com': '',
#  'redactionpolitics.com': 'Online/Digital',
#  'nature.org': 'Magazine',
#  'app.com': 'Newspaper',
#  'bangordailynews.com': 'Newspaper',
#  'globes.co.il': '',
#  'wizards.com': 'Podcast',
#  'nydailynews.com': 'Newspaper',
#  'bu.edu': '',
#  'daum.net': '',
#  'wvmetronews.com': 'Radio',
#  'wistv.com': 'Television',
#  'mlb.com': 'Podcast',
#  'ranker.com': '',
#  'airforcetimes.com': 'Newspaper',
#  'finbold.com': '',
#  'tweakers.net': 'Online/Digital',
#  'nbc.com': '',
#  'canberratimes.com.au': 'Newspaper',
#  'ubi.com': '',
#  'pff.com': '',
#  'elle.com': 'Magazine',
#  'deadspin.com': 'Online/Digital',
#  'dezeen.com': 'Online/Digital',
#  'pewresearch.org': 'Online/Digital',
#  'aier.org': 'Podcast',
#  'svt.se': 'Television',
#  'weather.com': 'Television',
#  'fair.org': 'Media Company',
#  'espn.co.uk': '',
#  'nbcsports.com': 'Podcast',
#  'maritime-executive.com': '',
#  'irishcentral.com': '',
#  'deccanherald.com': 'Podcast',
#  'skysports.com': 'Podcast',
#  'weny.com': 'Television',
#  'providencejournal.com': 'Newspaper',
#  'aa.com.tr': 'Newswire/News Agency',
#  'wpr.org': 'Podcast',
#  'planetary.org': 'Podcast',
#  'gamasutra.com': 'Online/Digital',
#  'sueddeutsche.de': 'Podcast',
#  'cheatsheet.com': '',
#  'kcrw.com': 'Podcast',
#  'yourtango.com': 'Blog',
#  'usnews.com': 'Online/Digital',
#  'theweek.in': 'Magazine',
#  'wbtv.com': '',
#  'complex.com': '',
#  'yardbarker.com': 'Online/Digital',
#  'kentucky.com': 'Newspaper',
#  'cnbctv18.com': '',
#  'realtor.com': 'Online/Digital',
#  'edmonton.ctvnews.ca': 'Television',
#  'wvlt.tv': 'Television',
#  'rfa.org': 'Podcast',
#  'slashdot.org': 'Online/Digital',
#  'seacoastonline.com': 'Newspaper',
#  'exclaim.ca': 'Magazine',
#  'koreaherald.com': 'Newspaper',
#  'bostonreview.net': 'Magazine',
#  'wustl.edu': 'Radio',
#  'slowboring.com': 'Newsletter (Digital)',
#  'leftvoice.org': 'Online/Digital',
#  'dicebreaker.com': 'Podcast',
#  'thescottishsun.co.uk': '',
#  'asm.org': 'Podcast',
#  'nba.com': 'Podcast',
#  'err.ee': 'Podcast',
#  'independent.co.uk': '',
#  'tunein.com': 'Podcast',
#  'msnbc.com': '',
#  'wset.com': 'Television',
#  'businesstoday.in': 'Magazine',
#  'news5cleveland.com': 'Television',
#  'ucsd.edu': 'Podcast',
#  'bongino.com': 'Podcast',
#  'thenational.scot': 'Podcast',
#  'mercola.com': 'Podcast',
#  'sportspromedia.com': 'Podcast',
#  'wcnc.com': 'Television',
#  'thecourier.co.uk': 'Newspaper',
#  'escapistmagazine.com': 'Podcast',
#  'boundingintocomics.com': '',
#  'ktvn.com': 'Television',
#  'wvnews.com': '',
#  'peta.org': 'Non-profit',
#  'nu.nl': 'Online/Digital',
#  'mediaite.com': 'Blog',
#  'alreporter.com': 'Online/Digital',
#  'wegotthiscovered.com': 'Online/Digital',
#  'pnas.org': '',
#  'jamanetwork.com': 'Podcast',
#  'mainichi.jp': '',
#  'lexology.com': 'Online/Digital',
#  'amny.com': 'Newsletter (Print)',
#  'bignewsnetwork.com': 'Online/Digital',
#  'famitsu.com': '',
#  'civileats.com': 'Online/Digital',
#  'phillymag.com': 'Magazine',
#  'lancasteronline.com': 'Newspaper',
#  'tomshardware.com': 'Online/Digital',
#  'techtimes.com': 'Online/Digital',
#  'foreignpolicy.com': 'Podcast',
#  'forward.com': 'Online/Digital',
#  'stackoverflow.blog': '',
#  'comicbookmovie.com': 'Online/Digital',
#  'bleacherreport.com': 'Media Company',
#  'firstpost.com': 'Online/Digital',
#  'airforcemag.com': 'Magazine',
#  'coinjournal.net': 'Online/Digital',
#  '972mag.com': 'Podcast',
#  'bnonews.com': '',
#  'hotcars.com': 'Online/Digital',
#  'state.gov': 'Podcast',
#  'acm.org': 'Magazine',
#  'wxii12.com': 'Television',
#  'stockx.com': 'Online/Digital',
#  'texasobserver.org': 'Newspaper',
#  'deseret.com': 'Newspaper',
#  'vtdigger.org': 'Online/Digital',
#  'clickhole.com': 'Online/Digital',
#  'pfizer.com': 'Corporate Newsroom',
#  'duluthnewstribune.com': 'Newspaper',
#  'thenewstribune.com': 'Newspaper',
#  'siasat.com': '',
#  'justia.com': '',
#  'wrtv.com': 'Television',
#  'news-journalonline.com': 'Newspaper',
#  'cancer.org': 'Podcast',
#  'nine.com.au': 'Online/Digital',
#  'thelily.com': 'Online/Digital',
#  'theonion.com': 'Online/Digital',
#  'thecentersquare.com': 'Podcast',
#  'unc.edu': 'Podcast',
#  'kvoa.com': 'Television',
#  'thepostmillennial.com': 'Online/Digital',
#  'siliconangle.com': '',
#  'androidheadlines.com': 'Newsletter (Digital)',
#  'oedigital.com': 'Online/Digital',
#  'dn.se': 'Online/Digital',
#  'kake.com': 'Television',
#  'labroots.com': 'Online/Digital',
#  'fox17.com': 'Television',
#  'leaderpost.com': 'Newspaper',
#  'usgs.gov': 'Podcast',
#  'thedrive.com': 'Online/Digital',
#  'spectrumlocalnews.com': 'Podcast',
#  'boardgamegeek.com': 'Online/Digital',
#  'financialpost.com': 'Newspaper',
#  'wfaa.com': 'Television Program',
#  'n-tv.de': 'Podcast',
#  'variety.com': 'Podcast',
#  'thisamericanlife.org': '',
#  'pressdemocrat.com': 'Newspaper',
#  'thebalance.com': 'Online/Digital',
#  'manchester.ac.uk': 'Podcast',
#  'thetelegraph.com': 'Newspaper',
#  'newsobserver.com': 'Newspaper',
#  'pcworld.com': 'Podcast',
#  'nme.com': 'Online/Digital',
#  'euroweeklynews.com': 'Newspaper',
#  'nhm.ac.uk': 'Podcast',
#  'datacenterdynamics.com': 'Online/Digital',
#  'yourstory.com': 'Online/Digital',
#  'newsone.com': 'Online/Digital',
#  'thecrimson.com': 'Newspaper',
#  'scroll.in': '',
#  'kare11.com': 'Television',
#  'nintendoeverything.com': '',
#  'masslive.com': 'Newspaper',
#  'ttnews.com': 'Podcast',
#  'newegg.com': 'Online/Digital',
#  'greekcitytimes.com': 'Newspaper',
#  'imore.com': '',
#  'interestingengineering.com': '',
#  'theedgemarkets.com': 'Magazine',
#  'click2houston.com': 'Television',
#  'boston.com': 'Online/Digital',
#  'nationalreview.com': 'Podcast',
#  'roarmag.org': '',
#  'psychiatrictimes.com': 'Podcast',
#  'cleantechnica.com': 'Online/Digital',
#  'roadandtrack.com': '',
#  'kxxv.com': 'Television',
#  'loudwire.com': '',
#  'zen.yandex.ru': 'Podcast',
#  'malaymail.com': '',
#  'freebeacon.com': 'Online/Digital',
#  'sfist.com': '',
#  'hillreporter.com': 'Online/Digital',
#  'nhk.or.jp': 'Podcast',
#  'stockhouse.com': '',
#  'nrk.no': 'Podcast',
#  'philstar.com': 'Newspaper',
#  'jewishjournal.com': 'Newspaper',
#  'theaustralian.com.au': 'Podcast',
#  'miragenews.com': 'Online/Digital',
#  'investopedia.com': '',
#  'hopkinsmedicine.org': 'Podcast',
#  'wreg.com': 'Television',
#  'cbs46.com': 'Television',
#  'burnabynow.com': 'Newspaper',
#  'insideevs.com': '',
#  'forbes.com': '',
#  'builtin.com': 'Online/Digital',
#  'lithub.com': 'Online/Digital',
#  'nikkei.com': 'Online/Digital',
#  'protocol.com': 'Newsletter (Digital)',
#  'citynews.ca': '',
#  'custhelp.com': '',
#  'whyy.org': 'Podcast',
#  'therevelator.org': 'Online/Digital',
#  'city-journal.org': 'Magazine',
#  'wdbj7.com': 'Television',
#  'sciencenews.org': '',
#  'mg.co.za': '',
#  'musicbusinessworldwide.com': 'Online/Digital',
#  'greenleft.org.au': 'Newspaper',
#  'seattletimes.com': 'Newsletter (Digital)',
#  'ft.com': 'Newsletter (Digital)',
#  'storenvy.com': 'Podcast',
#  'heart.org': 'Online/Digital',
#  'wearethemighty.com': 'Podcast',
#  'cryptoglobe.com': '',
#  'venturebeat.com': 'Online/Digital',
#  'inquisitr.com': 'Online/Digital',
#  'ufl.edu': 'Podcast',
#  'spectator.org': 'Magazine',
#  'oilprice.com': 'Online/Digital',
#  'spacenews.com': 'Magazine',
#  'ibtimes.com': '',
#  'thebeaverton.com': 'Television Program',
#  'ultimate-guitar.com': 'Online/Digital',
#  'wkyt.com': 'Television',
#  'zmescience.com': '',
#  'popculture.com': 'Online/Digital',
#  'welt.de': 'Podcast',
#  'santafenewmexican.com': '',
#  'news9.com': 'Television',
#  'wpri.com': 'Podcast',
#  'healthday.com': 'Online/Digital',
#  'zdf.de': 'Podcast',
#  'federalregister.gov': '',
#  'wboc.com': 'Television',
#  'itv.com': 'Television Program',
#  'freemalaysiatoday.com': 'Online/Digital',
#  'justgiving.com': 'Podcast',
#  'nj.com': 'Podcast',
#  'tor.com': '',
#  'somersetlive.co.uk': 'Magazine',
#  'military.com': 'Online/Digital',
#  'cell.com': '',
#  'tabletmag.com': 'Podcast',
#  'space.com': 'Online/Digital',
#  'wctv.tv': 'Television',
#  'ecosia.org': '',
#  'ethereumworldnews.com': 'Online/Digital',
#  'fox4news.com': 'Television',
#  'stitcher.com': 'Podcast',
#  'thestandard.com.hk': '',
#  'bbb.org': 'Podcast',
#  'livecoinwatch.com': '',
#  'wect.com': '',
#  'huffingtonpost.co.uk': 'Online/Digital',
#  'rgj.com': 'Newspaper',
#  'kerrang.com': 'Magazine',
#  'cbsnews.com': '',
#  'allure.com': 'Podcast',
#  'faroutmagazine.co.uk': 'Online/Digital',
#  'knock-la.com': '',
#  'smithsonianmag.com': 'Magazine',
#  'blackenterprise.com': 'Magazine',
#  'fox13news.com': 'Television',
#  'ctvnews.ca': '',
#  'nd.edu': 'Podcast',
#  'invezz.com': '',
#  'morningconsult.com': 'Online/Digital',
#  'sophos.com': 'Online/Digital',
#  'wsbtv.com': 'Television',
#  'twincities.com': 'Newspaper',
#  'culturemap.com': '',
#  'abc3340.com': 'Television',
#  'videogameschronicle.com': '',
#  'fresnobee.com': 'Newspaper',
#  'actionnetwork.com': 'Podcast',
#  'seekingalpha.com': 'Podcast',
#  'cargurus.com': '',
#  'grist.org': 'Online/Digital',
#  'cityandstateny.com': 'Newspaper',
#  'syracuse.com': 'Newspaper',
#  'hakaimagazine.com': 'Online/Digital',
#  'piunikaweb.com': '',
#  'ssa.gov': '',
#  'wfla.com': '',
#  'al-monitor.com': 'Online/Digital',
#  'news18.com': 'Online/Digital',
#  'xinhuanet.com': 'Newswire/News Agency',
#  'vice.com': 'Online/Digital',
#  'knoxnews.com': 'Newspaper',
#  'cambridge.org': 'Podcast',
#  'gizmodo.com': '',
#  'desmoinesregister.com': 'Newspaper',
#  'pionline.com': 'Newspaper',
#  'apnews.com': 'Newswire/News Agency',
#  'thepointsguy.com': 'Online/Digital',
#  'ted.com': 'Podcast',
#  'forkast.news': '',
#  'scitechdaily.com': '',
#  'psu.com': 'Online/Digital',
#  'torontosun.com': 'Newspaper',
#  'parliament.uk': 'Podcast',
#  'europarl.europa.eu': 'Podcast',
#  'eastidahonews.com': 'Online/Digital',
#  'hightimes.com': 'Magazine',
#  'mynews13.com': 'Television',
#  'nj1015.com': 'Radio',
#  'yna.co.kr': 'Newswire/News Agency',
#  'slate.com': 'Podcast',
#  'wtrf.com': 'Television',
#  'census.gov': 'Podcast',
#  'fextralife.com': 'Blog',
#  'khaleejtimes.com': 'Newspaper',
#  'fiercepharma.com': 'Newsletter (Digital)',
#  'sierraclub.org': 'Podcast',
#  'livemint.com': 'Podcast',
#  'nrc.nl': 'Newspaper',
#  'healthaffairs.org': 'Podcast',
#  'finextra.com': 'Online/Digital',
#  'law.com': 'Online/Digital',
#  'kjzz.org': 'Podcast',
#  'desertsun.com': 'Newspaper',
#  'catholicnewsagency.com': 'Podcast',
#  'live5news.com': 'Television',
#  'investors.com': 'OTT/Streaming',
#  'fc2.com': '',
#  'swr.de': 'Media Company',
#  'minnpost.com': 'Newspaper',
#  'theguardian.com': 'Newsletter (Digital)',
#  'iop.org': 'Journal',
#  'marca.com': 'Podcast',
#  'windsorstar.com': 'Newspaper',
#  'straitstimes.com': 'Podcast',
#  'screendaily.com': '',
#  'altpress.com': 'Magazine',
#  'theneweuropean.co.uk': 'Podcast',
#  'bgr.com': 'Blog',
#  'thebulletin.org': '',
#  'freecodecamp.org': 'Non-profit',
#  'toronto.com': 'Newspaper',
#  'wsws.org': 'Online/Digital',
#  'elespanol.com': 'Online/Digital',
#  'sportscasting.com': '',
#  'dailynews.com': 'Newspaper',
#  'myfox8.com': 'Television',
#  'ubc.ca': 'Podcast',
#  'appleinsider.com': 'Podcast',
#  'legalinsurrection.com': 'Online/Digital',
#  'france24.com': 'Podcast',
#  'gamingbolt.com': 'Online/Digital',
#  'dailycamera.com': 'Newspaper',
#  'ca.gov': 'Online/Digital',
#  'pitchfork.com': 'Blog',
#  'govtech.com': '',
#  'wltx.com': 'Television',
#  'mixmag.net': 'Magazine',
#  'fool.ca': '',
#  'mronline.org': 'Podcast',
#  'reason.com': 'Podcast',
#  'corriere.it': 'Podcast',
#  'radio-canada.ca': 'Podcast',
#  'rtings.com': '',
#  'peoplesworld.org': '',
#  'mentalfloss.com': 'Online/Digital',
#  'nbclosangeles.com': 'Television',
#  'inputmag.com': '',
#  'fox29.com': 'Television',
#  'mdpi.com': '',
#  'arte.tv': 'Television',
#  'lapresse.ca': 'Newspaper',
#  'infobae.com': 'Online/Digital',
#  'meduza.io': 'Podcast',
#  'michigan.gov': 'Podcast',
#  'energy.gov': 'Podcast',
#  'dailyhive.com': 'Newspaper',
#  'ineteconomics.org': 'Podcast',
#  'barrons.com': 'Podcast',
#  'odt.co.nz': 'Newspaper',
#  'bol.com': 'Podcast',
#  'watoday.com.au': 'Online/Digital',
#  'astronomy.com': 'Magazine',
#  'sentinelassam.com': '',
#  'uploadvr.com': 'Podcast',
#  'billboard.com': 'Podcast',
#  'globalcryptopress.com': 'Online/Digital',
#  'thv11.com': '',
#  'thespoon.tech': 'Online/Digital',
#  'allthatsinteresting.com': '',
#  'comingsoon.net': 'Online/Digital',
#  'westword.com': 'Newspaper',
#  'freethink.com': '',
#  'post-gazette.com': 'Newspaper',
#  'goodmenproject.com': '',
#  'michiganradio.org': 'Podcast',
#  'aawsat.com': 'Newspaper',
#  'stanford.edu': 'Podcast',
#  'kesq.com': '',
#  'infowars.com': 'Online/Digital',
#  'brusselstimes.com': 'Online/Digital',
#  'fox13now.com': 'Television',
#  'newscentermaine.com': 'Television',
#  'gaytimes.co.uk': 'Magazine',
#  'mobilesyrup.com': 'Online/Digital',
#  'mining.com': 'Online/Digital',
#  'ipsnews.net': '',
#  'cbs12.com': 'Television',
#  'cryptoslate.com': '',
#  'thequint.com': '',
#  'sbs.com.au': 'Podcast',
#  'al.com': 'Newspaper',
#  'journaldemontreal.com': 'Newspaper',
#  'azpbs.org': 'Television',
#  'pilotonline.com': 'Newspaper',
#  'greenvilleonline.com': 'Newspaper',
#  'autosport.com': 'Podcast',
#  'thespinoff.co.nz': '',
#  'hackaday.com': 'Blog',
#  'gamepressure.com': '',
#  'mondaq.com': 'Online/Digital',
#  'which.co.uk': 'Podcast',
#  'rcinet.ca': '',
#  '4chan.org': 'Podcast',
#  'wpxi.com': 'Television',
#  'clickorlando.com': 'Television',
#  'navalnews.com': 'Online/Digital',
#  'glassdoor.com': 'Blog',
#  'nation.com.pk': 'Newspaper',
#  'wral.com': 'Podcast',
#  'radiichina.com': 'Podcast',
#  'coindesk.com': 'Podcast',
#  'wsfa.com': 'Television',
#  'self.com': '',
#  'nautil.us': 'Magazine',
#  'allaboutcircuits.com': 'Podcast',
#  'mynews4.com': 'Television',
#  'autoblog.com': 'Podcast',
#  '10news.com': 'Television',
#  'kget.com': 'Television',
#  'gamerant.com': 'Online/Digital',
#  'undark.org': 'Podcast',
#  'ctpost.com': 'Newspaper',
#  'ncregister.com': 'Magazine',
#  'biospace.com': 'Online/Digital',
#  'lrt.lt': 'Television',
#  'torrentfreak.com': '',
#  'yourcentralvalley.com': 'Television',
#  'salon.com': '',
#  'middleeastmonitor.com': 'Online/Digital',
#  'ipolitics.ca': '',
#  'businessofapps.com': 'Podcast',
#  'autocar.co.uk': 'Magazine',
#  'news12.com': 'Television',
#  'insidehighered.com': 'Online/Digital',
#  'fossbytes.com': '',
#  'telegraaf.nl': 'Newspaper',
#  'ucr.edu': 'Podcast',
#  'scotusblog.com': '',
#  'coinpedia.org': '',
#  'harpersbazaar.com': 'Magazine',
#  'livelaw.in': '',
#  'techbullion.com': 'Online/Digital',
#  'wicz.com': 'Television',
#  'thelancet.com': 'Podcast',
#  'fas.org': 'Magazine',
#  'adidas.com': 'Podcast',
#  'techtarget.com': 'Online/Digital',
#  'nbcchicago.com': 'Television',
#  'vg.no': 'Podcast',
#  'wsoctv.com': 'Television',
#  'jns.org': 'Newswire/News Agency',
#  'brobible.com': 'Online/Digital',
#  'cryptobriefing.com': '',
#  'lavanguardia.com': 'Newspaper',
#  'abc57.com': 'Television',
#  'sundayguardianlive.com': 'Newspaper',
#  'spin.com': 'Online/Digital',
#  'chroniclelive.co.uk': 'Podcast',
#  'abovethelaw.com': 'Podcast',
#  'volkskrant.nl': 'Podcast',
#  'lightreading.com': 'Online/Digital',
#  'gamesindustry.biz': 'Online/Digital',
#  'politico.com': 'Newsletter (Digital)',
#  'einnews.com': 'Newswire/News Agency',
#  'morningstaronline.co.uk': 'Newspaper',
#  'fda.gov': 'Podcast',
#  'wbng.com': 'Television',
#  'rightwingwatch.org': 'Online/Digital',
#  'cinemablend.com': 'Blog',
#  'washingtontimes.com': 'Podcast',
#  ...}

# %%
len(set(media_type.values()))
# Out:
# 23

# %%
Counter(media_type.values())
# Out:
# Counter({'Podcast': 626,
#          '': 563,
#          'Online/Digital': 538,
#          'Television': 317,
#          'Magazine': 162,
#          'Newspaper': 270,
#          'Newsletter (Digital)': 26,
#          'Blog': 46,
#          'Journal': 16,
#          'Newsletter (Print)': 4,
#          'Radio Program': 4,
#          'Radio': 15,
#          'Television Program': 13,
#          'Newswire/News Agency': 19,
#          'Media Company': 4,
#          'Non-profit': 3,
#          'Corporate Newsroom': 1,
#          'OTT/Streaming': 2,
#          'Press release/News aggregator': 1,
#          'Broadcaster': 2,
#          'Podcast Network': 2,
#          'Research Company/Group': 4,
#          'Picture Agency': 1})

# %%
json.dump(media_type, open("media_type.json", "w", encoding="utf-8"))

# %% [markdown]
# ### According to old muck rack

# %%
clean_old_muckrack = dict()

for nsm in old_muckrack:
    extracted = tldextract.extract(nsm)
    subdomain, domain, suffix = extracted
    # add both versions of domain.suffix and subdomain.domain.suffix
    full = ""
    # with subdomain
    if len(subdomain) > 0:
        #print(f"{subdomain}.{domain}.{suffix}")
        full = f"{subdomain}.{domain}.{suffix}"
        if len(full) > 0:
            clean_old_muckrack[full.replace("www.","").strip('/')] = old_muckrack[nsm]
    # without subdomain
    full = f"{domain}.{suffix}"
    if len(full) > 0:
        clean_old_muckrack[full.replace("www.","").strip('/')] = old_muckrack[nsm]
len(clean_old_muckrack)
# Out:
# 67782

# %%
media_type_current = dict()

for k in ns_fixed_:
    media_type_current[k] = clean_old_muckrack[k][0]['instanceof'] if k in clean_old_muckrack else ''

# %%
media_type_current
# Out:
# {'crimeonline.com': 'Online/Digital',
#  'cornell.edu': 'Podcast',
#  'wealthsimple.com': 'Online/Digital',
#  'newscientist.com': 'Podcast',
#  'insider.com': 'Online/Digital',
#  'kcci.com': 'Television',
#  'hackernoon.com': 'Blog',
#  'thebetterindia.com': 'Online/Digital',
#  'wcpo.com': 'Television',
#  'theculturetrip.com': 'Online/Digital',
#  'king5.com': 'Television',
#  'runnersworld.com': 'Magazine',
#  'crimereads.com': 'Online/Digital',
#  'businessinsider.com': 'Financial/Market news, Online/Digital',
#  'futurism.com': 'Online/Digital',
#  'moneymorning.com': 'Online/Digital',
#  'applytojob.com': '',
#  'montgomeryadvertiser.com': 'Newspaper',
#  'mlbtraderumors.com': 'Online/Digital',
#  'gizchina.com': 'Media Company, Online/Digital',
#  'journaltimes.com': 'Newspaper',
#  'thegrio.com': 'Online/Digital',
#  'sfgate.com': 'Online/Digital',
#  'motortrend.com': 'Podcast, Television Program',
#  'thehindu.com': 'Online/Digital',
#  'uber.com': 'Blog',
#  'lasvegassun.com': 'Newspaper',
#  'metro.co.uk': 'Newspaper',
#  'musicradar.com': 'Online/Digital',
#  'californiaglobe.com': 'Online/Digital',
#  'nsf.gov': '',
#  'cnn.com': 'Podcast',
#  'americanprogress.org': 'Online/Digital',
#  '9to5mac.com': 'Newsletter (Digital)',
#  'timesnownews.com': 'Television',
#  'americamagazine.org': 'Magazine',
#  'ama-assn.org': 'Online/Digital',
#  'houstonpress.com': 'Newspaper',
#  'colorado.edu': '',
#  'bostonherald.com': 'Newspaper',
#  'eurogamer.net': '',
#  'kansascity.com': 'Newspaper',
#  'reviewjournal.com': 'Newspaper',
#  'businessinsider.com.au': 'Online/Digital',
#  'wired.co.uk': 'Magazine',
#  'rt.com': 'Online/Digital',
#  'theweek.com': 'Magazine',
#  'pasadenastarnews.com': 'Newspaper',
#  'elsevier.com': 'Journal',
#  'vancouverisland.ctvnews.ca': 'Television',
#  'pastemagazine.com': 'Podcast',
#  'looper.com': 'Online/Digital',
#  'cbs42.com': 'Television',
#  'waff.com': 'Television',
#  'techradar.com': 'Magazine',
#  'telegraph.co.uk': 'Newspaper, Online/Digital',
#  'sagepub.com': 'Magazine',
#  'newrepublic.com': 'Magazine',
#  'lesechos.fr': 'Online/Digital',
#  'toledoblade.com': 'Newspaper',
#  'renews.biz': 'Newsletter (Print)',
#  'breitbart.com': 'Newsletter (Digital)',
#  'wiktionary.org': '',
#  'sunjournal.com': 'Newspaper',
#  'outkick.com': 'Radio Program',
#  'nbc4i.com': 'Television',
#  'nerdwallet.com': 'Online/Digital',
#  'utexas.edu': '',
#  'lohud.com': 'Newspaper',
#  'tbsnews.net': 'Online/Digital',
#  'wkrn.com': 'Television',
#  'billingsgazette.com': 'Newspaper',
#  'staradvertiser.com': 'Newspaper',
#  'thesouthafrican.com': 'Online/Digital',
#  'engadget.com': 'Blog',
#  'mississippitoday.org': 'Online/Digital',
#  'techcrunch.com': 'Online/Digital',
#  'si.edu': 'Podcast',
#  'coventrytelegraph.net': 'Online/Digital',
#  'ky3.com': 'Television',
#  'breakingdefense.com': 'Online/Digital',
#  'wlky.com': 'Television',
#  'thoughtco.com': 'Online/Digital',
#  'msn.com': 'Online/Digital',
#  'business.site': 'Radio',
#  'simplywall.st': 'Online/Digital',
#  'freightwaves.com': 'Online/Digital',
#  'kusi.com': 'Television',
#  'pcgamesn.com': 'Online/Digital',
#  'bloombergquint.com': 'Online/Digital',
#  'fox10phoenix.com': 'Television',
#  'orlandosentinel.com': 'Newspaper',
#  'wlos.com': 'Television',
#  'mprnews.org': 'Radio',
#  'fox19.com': 'Television',
#  'foodnetwork.com': 'Television Program',
#  'wpcomstaging.com': '',
#  'swarajyamag.com': 'Magazine',
#  'deccanchronicle.com': 'Newspaper',
#  'motorauthority.com': 'Online/Digital',
#  'cntraveler.com': 'Magazine',
#  'autodesk.com': 'Online/Digital',
#  '20minutes.fr': 'Newspaper',
#  'psychiatryonline.org': 'Online/Digital',
#  'fox6now.com': 'Television',
#  'wmnf.org': 'Radio',
#  'dailystar.co.uk': 'Newspaper',
#  'silive.com': 'Newspaper',
#  'birminghammail.co.uk': 'Newspaper',
#  'americanmilitarynews.com': 'Online/Digital',
#  'unity.com': '',
#  'digitalmusicnews.com': 'Online/Digital',
#  'industryweek.com': 'Magazine',
#  'bfmtv.com': 'Media Company',
#  'winteriscoming.net': 'Online/Digital',
#  'mcall.com': 'Newspaper',
#  'letterboxd.com': '',
#  'insideclimatenews.org': 'Online/Digital',
#  'arabianbusiness.com': 'Magazine',
#  'cbs8.com': 'Television',
#  'hollywoodreporter.com': 'Podcast',
#  'fox40.com': 'Television',
#  'metalsucks.net': 'Online/Digital',
#  'solarpowerworldonline.com': 'Magazine',
#  'note.com': '',
#  'hyperallergic.com': 'Online/Digital',
#  'kctv5.com': 'Television',
#  'visualcapitalist.com': 'Online/Digital',
#  'portswigger.net': 'Online/Digital',
#  'physicsworld.com': 'Magazine',
#  'scotsman.com': 'Newsletter (Digital)',
#  'wbrc.com': 'Television',
#  'dallasnews.com': 'Newspaper',
#  'ktvz.com': 'Television',
#  'metrotimes.com': 'Newspaper',
#  'handelsblatt.com': 'Podcast',
#  'ucalgary.ca': 'Magazine',
#  'lawfareblog.com': 'Podcast',
#  'elconfidencial.com': 'Online/Digital',
#  'courtlistener.com': '',
#  'pcgamer.com': 'Magazine',
#  'quantamagazine.org': 'Podcast',
#  'virginiamercury.com': 'Online/Digital',
#  'ahajournals.org': 'Journal',
#  'katu.com': 'Television',
#  'local10.com': 'Television',
#  'theblaze.com': 'Podcast',
#  'whas11.com': 'Television',
#  'radio.com': 'Radio Program',
#  'wallofsoundau.com': '',
#  'indiatvnews.com': 'Television',
#  'listennotes.com': 'Podcast',
#  'okcfox.com': 'Television',
#  'iol.co.za': 'Newspaper',
#  'thelogicalindian.com': 'Newswire/News Agency',
#  'consortiumnews.com': 'Online/Digital',
#  'nationalgeographic.com': 'Magazine',
#  'elpais.com': 'Newsletter (Digital)',
#  'wtop.com': 'Radio',
#  'foxsports.com.au': 'Online/Digital',
#  'vnexpress.net': 'Online/Digital',
#  'prospectmagazine.co.uk': 'Magazine',
#  'theathletic.com': 'Podcast',
#  'defenseone.com': 'Online/Digital',
#  'empireonline.com': 'Magazine',
#  'keengamer.com': 'Online/Digital',
#  'edweek.org': 'Online/Digital',
#  'distrokid.com': '',
#  'leparisien.fr': 'Newspaper',
#  'driving.ca': 'Online/Digital',
#  'windows.com': '',
#  'tallahassee.com': 'Newspaper',
#  'ens-newswire.com': 'Newswire/News Agency',
#  'unlimitedhangout.com': '',
#  'fox59.com': 'Television',
#  'london.ctvnews.ca': 'Television',
#  'thenews.com.pk': 'Newspaper',
#  'dallasobserver.com': 'Newspaper',
#  'bbc.com': 'Online/Digital',
#  'grunge.com': 'Online/Digital',
#  'thisismoney.co.uk': 'Online/Digital',
#  'techpowerup.com': 'Online/Digital',
#  'inc.com': 'Podcast',
#  'scitation.org': 'Magazine',
#  'nasa.gov': 'Magazine',
#  'kark.com': 'Television',
#  'inthesetimes.com': 'Magazine',
#  'liberation.fr': 'Newspaper',
#  'saskatoon.ctvnews.ca': 'Television',
#  'minnesotareformer.com': 'Online/Digital',
#  'fortressofsolitude.co.za': 'Blog',
#  'mmafighting.com': 'Blog',
#  'ladbible.com': 'Online/Digital',
#  'hotair.com': 'Blog, Online/Digital',
#  'lifesitenews.com': 'Online/Digital',
#  'naturalnews.com': '',
#  'out.com': 'Magazine',
#  'nwaonline.com': 'Newspaper',
#  'repubblica.it': 'Newspaper',
#  'justthenews.com': 'Online/Digital',
#  'gobankingrates.com': 'Online/Digital',
#  'dcist.com': 'Blog',
#  'nairametrics.com': 'Online/Digital',
#  'thediplomat.com': 'Magazine',
#  'hbomax.com': 'OTT/Streaming',
#  'thoughtcatalog.com': 'Online/Digital',
#  'electrek.co': 'Online/Digital',
#  'ucsusa.org': 'Blog',
#  'gcs-web.com': '',
#  'ottawacitizen.com': 'Newspaper',
#  'cleanenergywire.org': 'Online/Digital',
#  'usf.edu': '',
#  'coloradopolitics.com': 'Online/Digital',
#  'thestate.com': 'Newspaper',
#  'wolfstreet.com': '',
#  'foxnews.com': 'Television Program',
#  'progressive.org': 'Magazine',
#  'latestly.com': 'Online/Digital',
#  'globenewswire.com': 'Newswire/News Agency, Press release/News aggregator',
#  'thedispatch.com': 'Podcast',
#  'pca.st': '',
#  'arabnews.com': 'Newspaper',
#  'mediamatters.org': 'Online/Digital',
#  'tim.blog': 'Podcast',
#  'essence.com': 'Podcast',
#  'fastcompany.com': 'Podcast',
#  'flipboard.com': 'Press release/News aggregator',
#  'citynews1130.com': 'Radio',
#  'crowdfundinsider.com': 'Online/Digital',
#  'wspa.com': 'Television',
#  'ieee.org': 'Magazine',
#  'flightradar24.com': '',
#  '5newsonline.com': 'Television',
#  'fxempire.com': 'Online/Digital',
#  'sandiegouniontribune.com': 'Podcast',
#  'goodhousekeeping.com': 'Magazine',
#  'palmbeachpost.com': 'Newspaper',
#  'statnews.com': 'Newsletter (Digital)',
#  'pe.com': 'Newspaper',
#  'sciencedirect.com': 'Journal',
#  'darkreading.com': 'Online/Digital',
#  'fivethirtyeight.com': 'Podcast',
#  'wkbw.com': 'Television',
#  'bookriot.com': 'Podcast',
#  'gsmarena.com': 'Online/Digital',
#  'abc.net.au': 'Podcast',
#  'aminoapps.com': '',
#  'gurufocus.com': 'Online/Digital',
#  'arkansasonline.com': 'Newspaper',
#  'drivetribe.com': 'Online/Digital',
#  'mdr.de': 'Broadcaster',
#  'capitalgazette.com': 'Newspaper',
#  'notebookcheck.net': 'Online/Digital',
#  'workers.org': '',
#  'cbsaustin.com': 'Television',
#  'junkee.com': 'Online/Digital',
#  'harpers.org': 'Magazine',
#  'saltwire.com': 'Newspaper',
#  'manofmany.com': 'Online/Digital',
#  'pocketgamer.com': 'Online/Digital',
#  'blu-ray.com': 'Online/Digital',
#  'euractiv.com': 'Online/Digital',
#  'canadiandimension.com': 'Magazine',
#  'thesource.com': 'Magazine',
#  'thenextweb.com': 'Online/Digital',
#  'torquenews.com': 'Blog',
#  'xsnoize.com': 'Online/Digital',
#  'natlawreview.com': 'Online/Digital',
#  'asianews.it': '',
#  'everythinglubbock.com': 'Television',
#  'heraldsun.com.au': 'Podcast',
#  'wwlp.com': 'Television',
#  'zycrypto.com': 'Online/Digital',
#  'fox35orlando.com': 'Television',
#  'umn.edu': 'Research Company/Group',
#  'greentechmedia.com': 'Online/Digital',
#  'bps.org.uk': 'Magazine',
#  'eenews.net': 'Online/Digital',
#  'dailyvoice.com': 'Online/Digital',
#  'bizjournals.com': 'Newspaper',
#  'dispatch.com': 'Newspaper',
#  'theday.com': 'Newspaper',
#  'abc7.com': 'Television',
#  'theafricareport.com': 'Magazine',
#  'wfsb.com': 'Television',
#  'carbuzz.com': 'Online/Digital',
#  'hellomagazine.com': 'Magazine',
#  'osu.edu': 'Podcast',
#  'zazzle.com': '',
#  'nsw.gov.au': 'Magazine',
#  'antiwar.com': 'Online/Digital',
#  'tripadvisor.com': 'Online/Digital',
#  'mit.edu': 'Newspaper',
#  'newson6.com': 'Television',
#  'inforum.com': 'Newspaper',
#  'rochester.edu': 'Journal',
#  'firstcoastnews.com': 'Television',
#  'bc.ctvnews.ca': 'Newspaper',
#  'rbth.com': 'Newspaper, Online/Digital',
#  'raspberrypi.org': 'Online/Digital',
#  'delish.com': 'Online/Digital',
#  'thecurrencyanalytics.com': '',
#  'spectator.us': 'Online/Digital',
#  'yougov.co.uk': 'Online/Digital',
#  'elitedaily.com': 'Online/Digital',
#  'pressprogress.ca': 'Online/Digital',
#  'caranddriver.com': 'Magazine',
#  'pinkvilla.com': 'Online/Digital',
#  'uw.edu': '',
#  'codepen.io': '',
#  '9to5google.com': 'Online/Digital',
#  'utah.gov': '',
#  'postandcourier.com': 'Newspaper',
#  'wsmv.com': 'Television',
#  'cmu.edu': '',
#  'staples.com': 'Magazine',
#  'insiderfinancial.com': '',
#  '10tv.com': 'Television',
#  'thetruthaboutguns.com': 'Blog',
#  'wric.com': 'Television',
#  'redstate.com': 'Blog',
#  'mymodernmet.com': 'Online/Digital',
#  'ct.gov': '',
#  'jacobinmag.com': 'Magazine',
#  'arstechnica.com': 'Online/Digital',
#  'wkyc.com': 'Television',
#  'scientificamerican.com': 'Podcast',
#  'businesstimes.com.sg': 'Newspaper',
#  'columbia.edu': 'Online/Digital',
#  'twinfinite.net': 'Online/Digital',
#  'list-manage.com': 'Newsletter (Digital)',
#  'mylondon.news': 'Newspaper',
#  'cp24.com': 'Newspaper',
#  'nationalinterest.org': 'Magazine',
#  'detroitnews.com': 'Podcast',
#  'edmontonjournal.com': 'Newspaper',
#  'thenationalpulse.com': 'Online/Digital',
#  'techstartups.com': 'Online/Digital',
#  'neocities.org': '',
#  'army.mil': 'Journal',
#  'player.fm': 'Podcast',
#  'westernstandardonline.com': 'Online/Digital',
#  'tmz.com': 'Newsletter (Digital)',
#  'reneweconomy.com.au': 'Online/Digital',
#  'brisbanetimes.com.au': 'Newspaper',
#  'rockpapershotgun.com': 'Online/Digital',
#  'adweek.com': 'Magazine',
#  'ifixit.com': 'Online/Digital',
#  'japan-forward.com': 'Online/Digital',
#  'coastreporter.net': 'Newspaper',
#  'jdsupra.com': 'Online/Digital',
#  'armradio.am': 'Radio',
#  'thebiglead.com': 'Blog',
#  'freakonomics.com': 'Podcast',
#  'wfpk.org': '',
#  'patheos.com': 'Online/Digital',
#  'dronedj.com': 'Online/Digital',
#  'libsyn.com': 'Podcast',
#  'buzzsprout.com': 'Podcast',
#  'knowyourmeme.com': 'Online/Digital',
#  'sciencetimes.com': 'Online/Digital',
#  '13abc.com': 'Television',
#  'thescore.com': 'Online/Digital',
#  'ktxs.com': 'Television',
#  'crosscut.com': 'Online/Digital',
#  'gulfnews.com': 'Newspaper',
#  'kmov.com': 'Television Program',
#  'dailymotion.com': '',
#  'todayonline.com': 'Newspaper',
#  'calgary.ctvnews.ca': 'Television',
#  'uwaterloo.ca': 'Magazine',
#  'hongkongfp.com': 'Online/Digital',
#  'businessinsider.co.za': '',
#  'pharmaceutical-technology.com': 'Magazine',
#  'goal.com': 'Online/Digital',
#  'telegram.com': 'Newspaper',
#  'khon2.com': 'Television',
#  'gothamist.com': 'Online/Digital',
#  'inverse.com': 'Podcast',
#  'fox8.com': 'Television',
#  'judicialwatch.org': 'Online/Digital',
#  'chtbl.com': 'Podcast',
#  'prweb.com': 'Press release/News aggregator',
#  'phoenixnewtimes.com': 'Newspaper',
#  'democratandchronicle.com': 'Newspaper',
#  'artofmanliness.com': 'Online/Digital',
#  'dawn.com': 'Newspaper',
#  'wallstreet-online.de': 'Financial/Market news',
#  'unl.edu': 'Magazine',
#  'studyfinds.org': 'Online/Digital',
#  'observador.pt': 'Newspaper',
#  'northjersey.com': 'Newspaper',
#  'thegrayzone.com': 'Online/Digital',
#  'truthout.org': 'Online/Digital',
#  'iphoneincanada.ca': 'Blog',
#  'ktvu.com': 'Television',
#  'marketbeat.com': 'Financial/Market news',
#  'kgw.com': 'Television',
#  'mercurynews.com': 'Newspaper',
#  'nsnews.com': 'Newspaper',
#  'gitconnected.com': '',
#  'starwars.com': 'Online/Digital',
#  'thelondoneconomic.com': 'Online/Digital',
#  'medicalnewstoday.com': 'Online/Digital',
#  'cbn.com': 'Television',
#  'oregonstate.edu': '',
#  'biologicaldiversity.org': 'Newsletter (Digital)',
#  'republicworld.com': 'Television',
#  'technologyreview.com': 'Podcast',
#  'popularmechanics.com': 'Magazine',
#  'courant.com': 'Newspaper',
#  'komonews.com': 'Television',
#  'hypebeast.com': 'Online/Digital',
#  'greencarreports.com': 'Online/Digital',
#  'newslaundry.com': 'Online/Digital',
#  'entrepreneur.com': 'Podcast',
#  'btcmanager.com': 'Online/Digital',
#  'shine.cn': 'Newspaper',
#  'gq-magazine.co.uk': 'Magazine',
#  'sciencealert.com': 'Online/Digital',
#  'thecut.com': 'Podcast',
#  'sun-sentinel.com': 'Newspaper',
#  'rfi.fr': 'Podcast, Radio Program',
#  'lcsun-news.com': 'Newspaper',
#  'nbcbayarea.com': 'Television',
#  'guitarcenter.com': 'Online/Digital',
#  'focus.de': 'Online/Digital',
#  'angel.co': '',
#  'prnewswire.co.uk': '',
#  'gatech.edu': '',
#  'elmundo.es': 'Online/Digital',
#  'qz.com': 'Newsletter (Digital)',
#  'dhakatribune.com': 'Newspaper',
#  'westerndigital.com': '',
#  'hubspot.com': 'Blog',
#  'newcannabisventures.com': 'Online/Digital',
#  'nhl.com': 'Online/Digital',
#  'kfor.com': 'Television',
#  'examinerlive.co.uk': 'Online/Digital',
#  'rochesterfirst.com': 'Television',
#  'beincrypto.com': 'Online/Digital',
#  'milenio.com': 'Television',
#  'force.com': '',
#  'supchina.com': 'Online/Digital',
#  'govexec.com': 'Magazine',
#  'pennlive.com': 'Newspaper',
#  'marketscreener.com': 'Financial/Market news',
#  'kenoshanews.com': 'Newspaper',
#  'wccftech.com': 'Magazine',
#  'sapo.pt': 'Online/Digital',
#  'ghacks.net': 'Online/Digital',
#  'vanguardngr.com': 'Magazine',
#  'franceinter.fr': 'Radio',
#  'jacksonville.com': 'Newspaper',
#  'reuters.com': 'Newswire/News Agency',
#  'pymnts.com': 'Online/Digital',
#  'uga.edu': '',
#  'in.gov': '',
#  'montrealgazette.com': 'Newspaper',
#  'realclearinvestigations.com': '',
#  'i24news.tv': 'Online/Digital',
#  'econotimes.com': 'Online/Digital',
#  'orlandoweekly.com': 'Newspaper',
#  'africanews.com': 'Online/Digital',
#  'buzzfeednews.com': 'OTT/Streaming',
#  'foreignaffairs.com': 'Magazine',
#  'dailykos.com': 'Online/Digital',
#  'cnnphilippines.com': 'Television',
#  'mindbodygreen.com': 'Online/Digital',
#  'cnbc.com': 'Television Program',
#  'cpr.org': 'Radio',
#  'palestinechronicle.com': 'Online/Digital',
#  'wkrg.com': 'Television',
#  'tvanouvelles.ca': 'Television',
#  'latimes.com': 'Newspaper',
#  'katc.com': 'Television',
#  'kpbs.org': 'Podcast',
#  'ktsm.com': 'Television',
#  'aphapublications.org': 'Newspaper',
#  'distractify.com': 'Online/Digital',
#  'hearthis.at': '',
#  'thethings.com': 'Online/Digital',
#  'kvia.com': 'Television',
#  'asu.edu': 'Journal',
#  'ap.org': 'Blog',
#  'uchicago.edu': 'Journal',
#  'podomatic.com': 'Podcast',
#  'kcra.com': 'Television',
#  'goodmorningamerica.com': 'Television Program',
#  'moneycontrol.com': 'Online/Digital',
#  'fox2now.com': 'Television',
#  'digitaltrends.com': 'Newsletter (Digital)',
#  'abcnews4.com': 'Television',
#  'vaticannews.va': '',
#  'dr.dk': 'Online/Digital',
#  'nysmusic.com': 'Online/Digital',
#  'artnews.com': 'Magazine',
#  'tulsaworld.com': 'Newspaper',
#  'townandcountrymag.com': 'Magazine',
#  'afr.com': 'Magazine',
#  'areomagazine.com': 'Magazine',
#  'eonline.com': 'Online/Digital',
#  'redactionpolitics.com': 'Online/Digital',
#  'nature.org': 'Magazine',
#  'app.com': 'Newspaper',
#  'bangordailynews.com': 'Newspaper',
#  'globes.co.il': 'Newspaper',
#  'wizards.com': '',
#  'nydailynews.com': 'Newspaper',
#  'bu.edu': 'Podcast',
#  'daum.net': '',
#  'wvmetronews.com': 'Radio',
#  'wistv.com': 'Television',
#  'mlb.com': 'Newsletter (Digital)',
#  'ranker.com': 'Online/Digital',
#  'airforcetimes.com': 'Newspaper',
#  'finbold.com': 'Online/Digital',
#  'tweakers.net': 'Online/Digital',
#  'nbc.com': 'Podcast, Television, Television Program',
#  'canberratimes.com.au': 'Newspaper',
#  'ubi.com': '',
#  'pff.com': '',
#  'elle.com': 'Magazine',
#  'deadspin.com': 'Online/Digital',
#  'dezeen.com': 'Online/Digital',
#  'pewresearch.org': 'Online/Digital',
#  'aier.org': '',
#  'svt.se': 'Television',
#  'weather.com': 'Podcast',
#  'fair.org': 'Media Company',
#  'espn.co.uk': '',
#  'nbcsports.com': 'Online/Digital',
#  'maritime-executive.com': 'Magazine',
#  'irishcentral.com': 'Online/Digital',
#  'deccanherald.com': 'Newspaper',
#  'skysports.com': 'Podcast',
#  'weny.com': 'Television',
#  'providencejournal.com': 'Newspaper',
#  'aa.com.tr': 'Newswire/News Agency',
#  'wpr.org': 'Podcast',
#  'planetary.org': '',
#  'gamasutra.com': 'Online/Digital',
#  'sueddeutsche.de': 'Magazine',
#  'cheatsheet.com': 'Online/Digital',
#  'kcrw.com': 'Podcast',
#  'yourtango.com': 'Blog',
#  'usnews.com': 'Online/Digital',
#  'theweek.in': 'Magazine',
#  'wbtv.com': 'Television',
#  'complex.com': 'Podcast',
#  'yardbarker.com': 'Online/Digital',
#  'kentucky.com': 'Newspaper',
#  'cnbctv18.com': 'Television',
#  'realtor.com': 'Online/Digital',
#  'edmonton.ctvnews.ca': 'Television',
#  'wvlt.tv': 'Television',
#  'rfa.org': 'Radio',
#  'slashdot.org': 'Online/Digital',
#  'seacoastonline.com': 'Newspaper',
#  'exclaim.ca': 'Magazine',
#  'koreaherald.com': 'Newspaper',
#  'bostonreview.net': 'Magazine',
#  'wustl.edu': 'Online/Digital',
#  'slowboring.com': 'Newsletter (Digital)',
#  'leftvoice.org': 'Online/Digital',
#  'dicebreaker.com': 'Online/Digital',
#  'thescottishsun.co.uk': 'Newspaper',
#  'asm.org': 'Journal',
#  'nba.com': 'Online/Digital',
#  'err.ee': 'Broadcaster',
#  'independent.co.uk': 'Podcast',
#  'tunein.com': 'Radio Program',
#  'msnbc.com': 'Television Program',
#  'wset.com': 'Television',
#  'businesstoday.in': 'Magazine',
#  'news5cleveland.com': 'Television',
#  'ucsd.edu': 'Magazine',
#  'bongino.com': 'Podcast',
#  'thenational.scot': 'Newspaper',
#  'mercola.com': '',
#  'sportspromedia.com': 'Magazine',
#  'wcnc.com': 'Television',
#  'thecourier.co.uk': 'Newspaper',
#  'escapistmagazine.com': 'Online/Digital',
#  'boundingintocomics.com': '',
#  'ktvn.com': 'Television',
#  'wvnews.com': 'Online/Digital',
#  'peta.org': 'Non-profit',
#  'nu.nl': 'Online/Digital',
#  'mediaite.com': 'Blog',
#  'alreporter.com': 'Online/Digital',
#  'wegotthiscovered.com': 'Online/Digital',
#  'pnas.org': 'Journal',
#  'jamanetwork.com': 'Podcast',
#  'mainichi.jp': 'Newspaper',
#  'lexology.com': 'Online/Digital',
#  'amny.com': 'Newspaper',
#  'bignewsnetwork.com': 'Online/Digital',
#  'famitsu.com': 'Magazine',
#  'civileats.com': 'Online/Digital',
#  'phillymag.com': 'Magazine',
#  'lancasteronline.com': 'Newspaper',
#  'tomshardware.com': 'Online/Digital',
#  'techtimes.com': 'Online/Digital',
#  'foreignpolicy.com': 'Newsletter (Digital)',
#  'forward.com': 'Magazine',
#  'stackoverflow.blog': 'Podcast',
#  'comicbookmovie.com': 'Online/Digital',
#  'bleacherreport.com': 'Podcast',
#  'firstpost.com': 'Online/Digital',
#  'airforcemag.com': 'Magazine',
#  'coinjournal.net': 'Online/Digital',
#  '972mag.com': 'Magazine',
#  'bnonews.com': 'Newswire/News Agency',
#  'hotcars.com': '',
#  'state.gov': '',
#  'acm.org': 'Magazine',
#  'wxii12.com': 'Television',
#  'stockx.com': 'Online/Digital',
#  'texasobserver.org': 'Newspaper',
#  'deseret.com': 'Newspaper',
#  'vtdigger.org': 'Online/Digital',
#  'clickhole.com': 'Online/Digital',
#  'pfizer.com': 'Corporate Newsroom',
#  'duluthnewstribune.com': 'Newspaper',
#  'thenewstribune.com': 'Newspaper',
#  'siasat.com': 'Online/Digital',
#  'justia.com': '',
#  'wrtv.com': 'Television',
#  'news-journalonline.com': 'Newspaper',
#  'cancer.org': '',
#  'nine.com.au': 'Online/Digital',
#  'thelily.com': 'Online/Digital',
#  'theonion.com': 'Online/Digital',
#  'thecentersquare.com': 'Online/Digital',
#  'unc.edu': 'Corporate Newsroom',
#  'kvoa.com': 'Television',
#  'thepostmillennial.com': 'Online/Digital',
#  'siliconangle.com': 'Blog',
#  'androidheadlines.com': 'Online/Digital',
#  'oedigital.com': 'Online/Digital',
#  'dn.se': 'Online/Digital',
#  'kake.com': 'Television',
#  'labroots.com': 'Online/Digital',
#  'fox17.com': 'Television',
#  'leaderpost.com': 'Newspaper',
#  'usgs.gov': '',
#  'thedrive.com': 'Online/Digital',
#  'spectrumlocalnews.com': 'Television',
#  'boardgamegeek.com': 'Online/Digital',
#  'financialpost.com': 'Newsletter (Digital)',
#  'wfaa.com': 'Television Program',
#  'n-tv.de': 'Television',
#  'variety.com': 'Television Program',
#  'thisamericanlife.org': 'Radio Program',
#  'pressdemocrat.com': 'Newspaper',
#  'thebalance.com': 'Online/Digital',
#  'manchester.ac.uk': '',
#  'thetelegraph.com': 'Newspaper',
#  'newsobserver.com': 'Newspaper',
#  'pcworld.com': 'Online/Digital',
#  'nme.com': 'Online/Digital',
#  'euroweeklynews.com': 'Newspaper',
#  'nhm.ac.uk': '',
#  'datacenterdynamics.com': 'Online/Digital',
#  'yourstory.com': 'Online/Digital',
#  'newsone.com': 'Online/Digital',
#  'thecrimson.com': 'Newspaper',
#  'scroll.in': 'Online/Digital',
#  'kare11.com': 'Television',
#  'nintendoeverything.com': 'Online/Digital',
#  'masslive.com': 'Online/Digital',
#  'ttnews.com': 'Newspaper',
#  'newegg.com': 'Online/Digital',
#  'greekcitytimes.com': 'Newspaper',
#  'imore.com': 'Online/Digital',
#  'interestingengineering.com': 'Online/Digital',
#  'theedgemarkets.com': 'Magazine',
#  'click2houston.com': 'Television',
#  'boston.com': 'Online/Digital',
#  'nationalreview.com': 'Podcast',
#  'roarmag.org': 'Magazine',
#  'psychiatrictimes.com': 'Magazine',
#  'cleantechnica.com': 'Online/Digital',
#  'roadandtrack.com': 'Magazine',
#  'kxxv.com': 'Television',
#  'loudwire.com': 'Online/Digital',
#  'zen.yandex.ru': '',
#  'malaymail.com': 'Newspaper',
#  'freebeacon.com': 'Online/Digital',
#  'sfist.com': 'Blog',
#  'hillreporter.com': 'Online/Digital',
#  'nhk.or.jp': 'OTT/Streaming, Radio, Television',
#  'stockhouse.com': '',
#  'nrk.no': 'Online/Digital',
#  'philstar.com': 'Newspaper',
#  'jewishjournal.com': 'Newspaper',
#  'theaustralian.com.au': 'Podcast',
#  'miragenews.com': 'Online/Digital',
#  'investopedia.com': 'Podcast',
#  'hopkinsmedicine.org': '',
#  'wreg.com': 'Television',
#  'cbs46.com': 'Television',
#  'burnabynow.com': 'Newspaper',
#  'insideevs.com': 'Podcast',
#  'forbes.com': 'Newsletter (Digital)',
#  'builtin.com': 'Online/Digital',
#  'lithub.com': '',
#  'nikkei.com': 'Online/Digital',
#  'protocol.com': 'Newsletter (Digital)',
#  'citynews.ca': 'Online/Digital',
#  'custhelp.com': '',
#  'whyy.org': 'Podcast',
#  'therevelator.org': 'Online/Digital',
#  'city-journal.org': 'Magazine',
#  'wdbj7.com': 'Television',
#  'sciencenews.org': 'Magazine',
#  'mg.co.za': 'Newspaper',
#  'musicbusinessworldwide.com': 'Online/Digital',
#  'greenleft.org.au': 'Newspaper',
#  'seattletimes.com': 'Newspaper',
#  'ft.com': 'Podcast',
#  'storenvy.com': '',
#  'heart.org': 'Magazine',
#  'wearethemighty.com': 'Podcast',
#  'cryptoglobe.com': 'Online/Digital',
#  'venturebeat.com': 'Online/Digital',
#  'inquisitr.com': 'Online/Digital',
#  'ufl.edu': '',
#  'spectator.org': 'Magazine',
#  'oilprice.com': 'Online/Digital',
#  'spacenews.com': 'Magazine',
#  'ibtimes.com': 'Online/Digital',
#  'thebeaverton.com': 'Television Program',
#  'ultimate-guitar.com': 'Online/Digital',
#  'wkyt.com': 'Television',
#  'zmescience.com': 'Online/Digital',
#  'popculture.com': 'Online/Digital',
#  'welt.de': 'Newspaper',
#  'santafenewmexican.com': 'Newspaper',
#  'news9.com': 'Television',
#  'wpri.com': 'Television',
#  'healthday.com': 'Online/Digital',
#  'zdf.de': 'Television',
#  'federalregister.gov': 'Online/Digital',
#  'wboc.com': 'Television',
#  'itv.com': 'Television Program',
#  'freemalaysiatoday.com': 'Online/Digital',
#  'justgiving.com': '',
#  'nj.com': 'Online/Digital',
#  'tor.com': 'Online/Digital',
#  'somersetlive.co.uk': 'Magazine',
#  'military.com': 'Online/Digital',
#  'cell.com': 'Journal',
#  'tabletmag.com': 'Magazine',
#  'space.com': 'Online/Digital',
#  'wctv.tv': 'Television',
#  'ecosia.org': 'Podcast',
#  'ethereumworldnews.com': 'Online/Digital',
#  'fox4news.com': 'Television',
#  'stitcher.com': 'Podcast',
#  'thestandard.com.hk': 'Newspaper',
#  'bbb.org': '',
#  'livecoinwatch.com': '',
#  'wect.com': 'Television',
#  'huffingtonpost.co.uk': 'Podcast',
#  'rgj.com': 'Newspaper',
#  'kerrang.com': 'Magazine',
#  'cbsnews.com': 'OTT/Streaming',
#  'allure.com': 'Magazine',
#  'faroutmagazine.co.uk': 'Online/Digital',
#  'knock-la.com': 'Online/Digital',
#  'smithsonianmag.com': 'Magazine',
#  'blackenterprise.com': 'Magazine',
#  'fox13news.com': 'Television',
#  'ctvnews.ca': 'Newspaper',
#  'nd.edu': 'Magazine, Online/Digital',
#  'invezz.com': 'Online/Digital',
#  'morningconsult.com': 'Online/Digital',
#  'sophos.com': 'Online/Digital',
#  'wsbtv.com': 'Television',
#  'twincities.com': 'Newspaper',
#  'culturemap.com': 'Online/Digital',
#  'abc3340.com': 'Television',
#  'videogameschronicle.com': '',
#  'fresnobee.com': 'Newspaper',
#  'actionnetwork.com': 'Online/Digital',
#  'seekingalpha.com': 'Podcast',
#  'cargurus.com': 'Online/Digital',
#  'grist.org': 'Online/Digital',
#  'cityandstateny.com': 'Newspaper',
#  'syracuse.com': 'Newspaper',
#  'hakaimagazine.com': 'Online/Digital',
#  'piunikaweb.com': '',
#  'ssa.gov': '',
#  'wfla.com': 'Television',
#  'al-monitor.com': 'Online/Digital',
#  'news18.com': 'Online/Digital',
#  'xinhuanet.com': 'Newswire/News Agency',
#  'vice.com': 'Online/Digital',
#  'knoxnews.com': 'Newspaper',
#  'cambridge.org': 'Journal',
#  'gizmodo.com': 'Online/Digital',
#  'desmoinesregister.com': 'Newspaper',
#  'pionline.com': 'Newspaper',
#  'apnews.com': 'Newspaper',
#  'thepointsguy.com': 'Podcast',
#  'ted.com': 'Podcast',
#  'forkast.news': 'Online/Digital',
#  'scitechdaily.com': 'Online/Digital',
#  'psu.com': 'Online/Digital',
#  'torontosun.com': 'Newspaper',
#  'parliament.uk': 'Online/Digital',
#  'europarl.europa.eu': '',
#  'eastidahonews.com': 'Online/Digital',
#  'hightimes.com': 'Magazine',
#  'mynews13.com': 'Television',
#  'nj1015.com': 'Radio',
#  'yna.co.kr': 'Newswire/News Agency',
#  'slate.com': 'Podcast',
#  'wtrf.com': 'Television',
#  'census.gov': '',
#  'fextralife.com': '',
#  'khaleejtimes.com': 'Newspaper',
#  'fiercepharma.com': 'Newsletter (Digital)',
#  'sierraclub.org': 'Magazine',
#  'livemint.com': 'Podcast',
#  'nrc.nl': 'Newspaper',
#  'healthaffairs.org': 'Journal',
#  'finextra.com': 'Online/Digital',
#  'law.com': 'Newspaper',
#  'kjzz.org': 'Radio',
#  'desertsun.com': 'Newspaper',
#  'catholicnewsagency.com': 'Online/Digital',
#  'live5news.com': 'Television',
#  'investors.com': 'Newspaper',
#  'fc2.com': '',
#  'swr.de': '',
#  'minnpost.com': 'Newspaper',
#  'theguardian.com': 'Newsletter (Digital)',
#  'iop.org': 'Journal',
#  'marca.com': 'Newspaper',
#  'windsorstar.com': 'Newspaper',
#  'straitstimes.com': 'Podcast',
#  'screendaily.com': 'Magazine',
#  'altpress.com': 'Magazine',
#  'theneweuropean.co.uk': 'Newspaper',
#  'bgr.com': 'Newsletter (Digital)',
#  'thebulletin.org': 'Magazine',
#  'freecodecamp.org': '',
#  'toronto.com': 'Newspaper',
#  'wsws.org': '',
#  'elespanol.com': 'Online/Digital',
#  'sportscasting.com': 'Online/Digital',
#  'dailynews.com': 'Newspaper',
#  'myfox8.com': 'Television',
#  'ubc.ca': 'Online/Digital',
#  'appleinsider.com': 'Podcast',
#  'legalinsurrection.com': 'Online/Digital',
#  'france24.com': 'Television Program',
#  'gamingbolt.com': 'Online/Digital',
#  'dailycamera.com': 'Newspaper',
#  'ca.gov': 'Online/Digital',
#  'pitchfork.com': 'Blog',
#  'govtech.com': 'Magazine',
#  'wltx.com': 'Television',
#  'mixmag.net': 'Magazine',
#  'fool.ca': 'Online/Digital',
#  'mronline.org': '',
#  'reason.com': 'Magazine',
#  'corriere.it': 'Online/Digital',
#  'radio-canada.ca': 'Television',
#  'rtings.com': 'Online/Digital',
#  'peoplesworld.org': 'Online/Digital',
#  'mentalfloss.com': 'Online/Digital',
#  'nbclosangeles.com': 'Television',
#  'inputmag.com': 'Online/Digital',
#  'fox29.com': 'Television',
#  'mdpi.com': 'Research Company/Group',
#  'arte.tv': 'Television Program',
#  'lapresse.ca': 'Newspaper',
#  'infobae.com': 'Online/Digital',
#  'meduza.io': 'Online/Digital',
#  'michigan.gov': '',
#  'energy.gov': 'Podcast',
#  'dailyhive.com': 'Newspaper',
#  'ineteconomics.org': '',
#  'barrons.com': 'Magazine',
#  'odt.co.nz': 'Newspaper',
#  'bol.com': '',
#  'watoday.com.au': 'Online/Digital',
#  'astronomy.com': 'Magazine',
#  'sentinelassam.com': 'Newspaper',
#  'uploadvr.com': 'Online/Digital',
#  'billboard.com': 'Magazine',
#  'globalcryptopress.com': 'Online/Digital',
#  'thv11.com': 'Television',
#  'thespoon.tech': 'Online/Digital',
#  'allthatsinteresting.com': 'Online/Digital',
#  'comingsoon.net': 'Online/Digital',
#  'westword.com': 'Newspaper',
#  'freethink.com': 'Online/Digital',
#  'post-gazette.com': 'Newspaper',
#  'goodmenproject.com': 'Media Company, Online/Digital',
#  'michiganradio.org': 'Radio',
#  'aawsat.com': 'Newspaper',
#  'stanford.edu': 'Journal',
#  'kesq.com': 'Television',
#  'infowars.com': 'Online/Digital',
#  'brusselstimes.com': 'Online/Digital',
#  'fox13now.com': 'Television',
#  'newscentermaine.com': 'Television',
#  'gaytimes.co.uk': 'Magazine',
#  'mobilesyrup.com': '',
#  'mining.com': 'Online/Digital',
#  'ipsnews.net': 'Newswire/News Agency',
#  'cbs12.com': 'Television',
#  'cryptoslate.com': 'Online/Digital',
#  'thequint.com': 'Online/Digital',
#  'sbs.com.au': 'Podcast',
#  'al.com': 'Newspaper',
#  'journaldemontreal.com': 'Newspaper',
#  'azpbs.org': 'Newswire/News Agency',
#  'pilotonline.com': 'Newspaper',
#  'greenvilleonline.com': 'Newspaper',
#  'autosport.com': 'Podcast',
#  'thespinoff.co.nz': 'Online/Digital',
#  'hackaday.com': 'Blog',
#  'gamepressure.com': '',
#  'mondaq.com': 'Online/Digital',
#  'which.co.uk': 'Online/Digital',
#  'rcinet.ca': 'Media Company',
#  '4chan.org': '',
#  'wpxi.com': 'Television',
#  'clickorlando.com': 'Television',
#  'navalnews.com': 'Online/Digital',
#  'glassdoor.com': 'Blog',
#  'nation.com.pk': 'Newspaper',
#  'wral.com': 'Podcast',
#  'radiichina.com': 'Online/Digital',
#  'coindesk.com': 'Newsletter (Digital)',
#  'wsfa.com': 'Television',
#  'self.com': 'Online/Digital',
#  'nautil.us': 'Magazine',
#  'allaboutcircuits.com': 'Online/Digital',
#  'mynews4.com': 'Television',
#  'autoblog.com': 'Podcast',
#  '10news.com': 'Television',
#  'kget.com': 'Television',
#  'gamerant.com': 'Online/Digital',
#  'undark.org': 'Podcast',
#  'ctpost.com': 'Newspaper',
#  'ncregister.com': 'Magazine',
#  'biospace.com': 'Online/Digital',
#  'lrt.lt': 'Television',
#  'torrentfreak.com': 'Online/Digital',
#  'yourcentralvalley.com': 'Television',
#  'salon.com': 'Online/Digital',
#  'middleeastmonitor.com': 'Online/Digital',
#  'ipolitics.ca': 'Online/Digital',
#  'businessofapps.com': 'Online/Digital',
#  'autocar.co.uk': 'Magazine',
#  'news12.com': 'Television',
#  'insidehighered.com': 'Online/Digital',
#  'fossbytes.com': 'Magazine',
#  'telegraaf.nl': 'Newspaper',
#  'ucr.edu': '',
#  'scotusblog.com': 'Magazine',
#  'coinpedia.org': '',
#  'harpersbazaar.com': 'Magazine',
#  'livelaw.in': 'Online/Digital',
#  'techbullion.com': 'Online/Digital',
#  'wicz.com': 'Television',
#  'thelancet.com': 'Journal',
#  'fas.org': 'Magazine',
#  'adidas.com': '',
#  'techtarget.com': 'Online/Digital',
#  'nbcchicago.com': 'Television',
#  'vg.no': 'Online/Digital',
#  'wsoctv.com': 'Television',
#  'jns.org': 'Newswire/News Agency',
#  'brobible.com': 'Online/Digital',
#  'cryptobriefing.com': 'Online/Digital',
#  'lavanguardia.com': 'Newspaper',
#  'abc57.com': 'Television',
#  'sundayguardianlive.com': 'Newspaper',
#  'spin.com': 'Online/Digital',
#  'chroniclelive.co.uk': 'Podcast',
#  'abovethelaw.com': 'Online/Digital',
#  'volkskrant.nl': 'Newspaper',
#  'lightreading.com': 'Online/Digital',
#  'gamesindustry.biz': 'Online/Digital',
#  'politico.com': 'Newsletter (Digital)',
#  'einnews.com': 'Newswire/News Agency',
#  'morningstaronline.co.uk': 'Newspaper',
#  'fda.gov': '',
#  'wbng.com': 'Television',
#  'rightwingwatch.org': 'Online/Digital',
#  'cinemablend.com': 'Blog',
#  'washingtontimes.com': 'Podcast',
#  ...}

# %%
json.dump(media_type_current, open("media_type_current.json", "w", encoding="utf-8"))

# %% [markdown]
# ## Country

# %%
country = dict()

for k in ns_fixed_:
    country[k] = clean_old_muckrack[k][0]['country'] if k in clean_old_muckrack else ''

# %%
Counter(country.values())
# Out:
# Counter({'': 2639})
