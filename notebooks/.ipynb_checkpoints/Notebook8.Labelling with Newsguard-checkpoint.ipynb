# %% [markdown]
# # Labelling with Newsguard

# %%
import os
import json

from collections import Counter, defaultdict

import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd1 = os.path.split(os.getcwd())[0]
data_fp = os.path.join(pd1,"data/gm-newssources-subreddits")
dfp = os.path.join(pd1,"data")
mbfc_path = os.path.join(pd1, "data/mbfc")
newsguard_path = os.path.join(pd1, "data/newsguard")

# %% [markdown]
# ## Reading Newsguard

# %%
newsguard = json.load(open(os.path.join(newsguard_path, "newsguard.json")))

# %%
len(newsguard)
# Out:
# 3887

# %%
ns_newsguard = list(newsguard.keys())

# %% [markdown]
# ## Finding intersection between current news sources and newsguard data

# %%
ns_fixed = json.load(open("ns_fixed.json", "r"))

# %%
len(ns_fixed)
# Out:
# 2643

# %%
intersection = set(ns_newsguard) & set(ns_fixed)
len(intersection)
# Out:
# 784

# %%
newsguard["wtop.com"].keys()
# Out:
# dict_keys(['rating_score', 'ownership', 'financing', 'content', 'credibility', 'transparency', 'history', 'rated', '1)no false content', '2)responsible presentation', '3)corrects errors', '4)distinguishes news & opinion', '5)no deceptive headlines', '6)ownership disclosed', '7)labels advertising', '8)transparent leadership', '9)names content creators'])

# %%
rated = [(i,newsguard[i]["rating_score"])  for i in intersection if newsguard[i]["rating_score"] != "n/a"]
len(rated)
# Out:
# 341

# %%
intersection - set([k[0] for k in rated])
# Out:
# {'10news.com',
#  '10tv.com',
#  '13abc.com',
#  '13newsnow.com',
#  '14news.com',
#  '4029tv.com',
#  '5newsonline.com',
#  '972mag.com',
#  '9news.com',
#  '9news.com.au',
#  'abc.net.au',
#  'abc17news.com',
#  'abc30.com',
#  'abc3340.com',
#  'abc57.com',
#  'abc6onyourside.com',
#  'acast.com',
#  'actionnewsnow.com',
#  'ad.nl',
#  'adn.com',
#  'afr.com',
#  'africanews.com',
#  'al-monitor.com',
#  'alarabiya.net',
#  'allafrica.com',
#  'allure.com',
#  'ama-assn.org',
#  'americanbanker.com',
#  'americansongwriter.com',
#  'androidauthority.com',
#  'androidcentral.com',
#  'androidpolice.com',
#  'aptnnews.ca',
#  'arktimes.com',
#  'arte.tv',
#  'asiaone.com',
#  'autocar.co.uk',
#  'aviationweek.com',
#  'azfamily.com',
#  'azpbs.org',
#  'bakersfield.com',
#  'bangkokpost.com',
#  'bigissue.com',
#  'biologicaldiversity.org',
#  'biorxiv.org',
#  'bitcoinmagazine.com',
#  'blabbermouth.net',
#  'bloody-disgusting.com',
#  'bonappetit.com',
#  'bostonreview.net',
#  'breakingnews.ie',
#  'broadwayworld.com',
#  'burnabynow.com',
#  'business-standard.com',
#  'bworldonline.com',
#  'caixinglobal.com',
#  'canberratimes.com.au',
#  'caranddriver.com',
#  'cargurus.com',
#  'cartoonbrew.com',
#  'cbs12.com',
#  'cbs8.com',
#  'cbsaustin.com',
#  'channel3000.com',
#  'chattanoogan.com',
#  'cheknews.ca',
#  'cityandstateny.com',
#  'classicfm.com',
#  'cleantechnica.com',
#  'cnnphilippines.com',
#  'collider.com',
#  'comedy.co.uk',
#  'comicbook.com',
#  'computerweekly.com',
#  'computerworld.com',
#  'cp24.com',
#  'cracked.com',
#  'crikey.com.au',
#  'ctmirror.org',
#  'cyclingnews.com',
#  'cyprus-mail.com',
#  'darkreading.com',
#  'deccanchronicle.com',
#  'delish.com',
#  'democracynow.org',
#  'destructoid.com',
#  'dexerto.com',
#  'dmagazine.com',
#  'dpreview.com',
#  'dsogaming.com',
#  'edmontonjournal.com',
#  'electronicintifada.net',
#  'elespanol.com',
#  'elitedaily.com',
#  'empireonline.com',
#  'ens-newswire.com',
#  'etonline.com',
#  'euobserver.com',
#  'ewn.co.za',
#  'expressen.se',
#  'extremetech.com',
#  'famitsu.com',
#  'filmdaily.co',
#  'firstcoastnews.com',
#  'firstpost.com',
#  'flickeringmyth.com',
#  'fox17.com',
#  'fox19.com',
#  'fox35orlando.com',
#  'fox5vegas.com',
#  'fox61.com',
#  'fox6now.com',
#  'fox8live.com',
#  'foxbaltimore.com',
#  'foxcarolina.com',
#  'foxsanantonio.com',
#  'freethink.com',
#  'frontiersin.org',
#  'futurity.org',
#  'gamesradar.com',
#  'gamewatcher.com',
#  'genengnews.com',
#  'geo.tv',
#  'ghacks.net',
#  'gizmodo.com.au',
#  'gmanetwork.com',
#  'greekreporter.com',
#  'greenleft.org.au',
#  'grist.org',
#  'gsmarena.com',
#  'guampdn.com',
#  'haaretz.com',
#  'hani.co.kr',
#  'hawaiinewsnow.com',
#  'healthaffairs.org',
#  'hellomagazine.com',
#  'heraldsun.com.au',
#  'highsnobiety.com',
#  'hotnewhiphop.com',
#  'howstuffworks.com',
#  'hyperallergic.com',
#  'idahonews.com',
#  'iheart.com',
#  'independent.ie',
#  'indiatvnews.com',
#  'infoq.com',
#  'insidernj.com',
#  'insidethegames.biz',
#  'instyle.com',
#  'intellinews.com',
#  'inverse.com',
#  'investing.com',
#  'iol.co.za',
#  'irishmirror.ie',
#  'israelhayom.com',
#  'israelnationalnews.com',
#  'japan-forward.com',
#  'japantimes.co.jp',
#  'jns.org',
#  'journaldemontreal.com',
#  'kake.com',
#  'katc.com',
#  'katu.com',
#  'kcci.com',
#  'kcra.com',
#  'kens5.com',
#  'kesq.com',
#  'ketv.com',
#  'kfgo.com',
#  'kfoxtv.com',
#  'kgw.com',
#  'khaleejtimes.com',
#  'khq.com',
#  'kicker.de',
#  'kitv.com',
#  'kjrh.com',
#  'kjzz.org',
#  'kktv.com',
#  'kltv.com',
#  'kmbc.com',
#  'kmov.com',
#  'kob.com',
#  'koco.com',
#  'koreaherald.com',
#  'kotaku.com.au',
#  'kplctv.com',
#  'kptv.com',
#  'kpvi.com',
#  'krcrtv.com',
#  'krem.com',
#  'ksat.com',
#  'ksby.com',
#  'ksdk.com',
#  'kshb.com',
#  'ksl.com',
#  'kstp.com',
#  'ktul.com',
#  'ktvb.com',
#  'ktvn.com',
#  'ktvz.com',
#  'ktxs.com',
#  'kusi.com',
#  'kutv.com',
#  'kvia.com',
#  'kvoa.com',
#  'kvue.com',
#  'kwch.com',
#  'kwwl.com',
#  'kxly.com',
#  'kxxv.com',
#  'ky3.com',
#  'lapresse.ca',
#  'lareviewofbooks.org',
#  'lasvegassun.com',
#  'law360.com',
#  'lbc.co.uk',
#  'legacy.com',
#  'lex18.com',
#  'lfpress.com',
#  'live5news.com',
#  'livemint.com',
#  'local10.com',
#  'local12.com',
#  'lrb.co.uk',
#  'lrt.lt',
#  'mainichi.jp',
#  'marca.com',
#  'marvel.com',
#  'mb.com.ph',
#  'mcsweeneys.net',
#  'meduza.io',
#  'metalinjection.net',
#  'metroweekly.com',
#  'mg.co.za',
#  'milenio.com',
#  'mlbtraderumors.com',
#  'moneycontrol.com',
#  'monthlyreview.org',
#  'moroccoworldnews.com',
#  'motortrend.com',
#  'movieweb.com',
#  'mynews13.com',
#  'mynews4.com',
#  'nakedcapitalism.com',
#  'nasaspaceflight.com',
#  'natalie.mu',
#  'natlawreview.com',
#  'nbc-2.com',
#  'nbc.com',
#  'nbc12.com',
#  'nbc29.com',
#  'nbc4i.com',
#  'nbcmiami.com',
#  'nbcmontana.com',
#  'nbcsandiego.com',
#  'ndtv.com',
#  'neowin.net',
#  'news24.com',
#  'news4jax.com',
#  'news4sanantonio.com',
#  'news9.com',
#  'newscentermaine.com',
#  'newschannel5.com',
#  'newschannel9.com',
#  'newson6.com',
#  'nextgov.com',
#  'nintendolife.com',
#  'nme.com',
#  'nos.nl',
#  'novaramedia.com',
#  'nrk.no',
#  'nst.com.my',
#  'ny1.com',
#  'nzherald.co.nz',
#  'observador.pt',
#  'oecd.org',
#  'okcfox.com',
#  'opb.org',
#  'pcmag.com',
#  'peoplesworld.org',
#  'petapixel.com',
#  'phoronix.com',
#  'playbill.com',
#  'polygon.com',
#  'progressive.org',
#  'quillette.com',
#  'radiotimes.com',
#  'rappler.com',
#  'realtor.com',
#  'rediff.com',
#  'refinery29.com',
#  'reliefweb.int',
#  'ria.ru',
#  'rockpapershotgun.com',
#  'rottentomatoes.com',
#  'rthk.hk',
#  'rtl.lu',
#  'rtlnieuws.nl',
#  'rtp.pt',
#  'rudaw.net',
#  'samaa.tv',
#  'sbs.com.au',
#  'screendaily.com',
#  'shacknews.com',
#  'shine.cn',
#  'sixthtone.com',
#  'sky.com',
#  'skysports.com',
#  'slashdot.org',
#  'slashfilm.com',
#  'smh.com.au',
#  'sportskeeda.com',
#  'springer.com',
#  'stanforddaily.com',
#  'startribune.com',
#  'statista.com',
#  'stereogum.com',
#  'straitstimes.com',
#  'sverigesradio.se',
#  'svt.se',
#  'taiwannews.com.tw',
#  'tandfonline.com',
#  'techraptor.net',
#  'techrepublic.com',
#  'techspot.com',
#  'telegraaf.nl',
#  'theage.com.au',
#  'thebeaverton.com',
#  'thecrimson.com',
#  'thedenverchannel.com',
#  'thediplomat.com',
#  'thehindu.com',
#  'theinformation.com',
#  'thenewsminute.com',
#  'theonion.com',
#  'theparisreview.org',
#  'thepointsguy.com',
#  'thepostmillennial.com',
#  'theprint.in',
#  'thequint.com',
#  'theringer.com',
#  'thewalrus.ca',
#  'theweathernetwork.com',
#  'thewest.com.au',
#  'thv11.com',
#  'timescolonist.com',
#  'timesofmalta.com',
#  'tmj4.com',
#  'tolonews.com',
#  'tor.com',
#  'trueachievements.com',
#  'trustedreviews.com',
#  'tsn.ca',
#  'turnto10.com',
#  'tvanouvelles.ca',
#  'tvnz.co.nz',
#  'tvo.org',
#  'twinfinite.net',
#  'ucdavis.edu',
#  'ultimateclassicrock.com',
#  'unherd.com',
#  'uol.com.br',
#  'urdupoint.com',
#  'usni.org',
#  'vancouversun.com',
#  'vg.no',
#  'wafb.com',
#  'waff.com',
#  'wallstreet-online.de',
#  'watoday.com.au',
#  'wbir.com',
#  'wbng.com',
#  'wboc.com',
#  'wbrz.com',
#  'wbtv.com',
#  'wcnc.com',
#  'wcpo.com',
#  'wdbj7.com',
#  'wdrb.com',
#  'wdsu.com',
#  'weartv.com',
#  'wect.com',
#  'wesh.com',
#  'wfmj.com',
#  'wfmynews2.com',
#  'wfmz.com',
#  'wfsb.com',
#  'wgal.com',
#  'wgrz.com',
#  'whas11.com',
#  'whatculture.com',
#  'which.co.uk',
#  'whsv.com',
#  'wicz.com',
#  'windowscentral.com',
#  'windsorstar.com',
#  'winknews.com',
#  'winnipegfreepress.com',
#  'wishtv.com',
#  'wisn.com',
#  'wistv.com',
#  'wkbw.com',
#  'wkow.com',
#  'wkyc.com',
#  'wlbt.com',
#  'wlky.com',
#  'wlos.com',
#  'wlox.com',
#  'wltx.com',
#  'wlwt.com',
#  'wmbfnews.com',
#  'wmcactionnews5.com',
#  'wmnf.org',
#  'wmtw.com',
#  'wmur.com',
#  'wnep.com',
#  'wowt.com',
#  'wpde.com',
#  'wptv.com',
#  'wral.com',
#  'wrcbtv.com',
#  'wrdw.com',
#  'wrex.com',
#  'wsaz.com',
#  'wset.com',
#  'wsfa.com',
#  'wsiltv.com',
#  'wsls.com',
#  'wsmv.com',
#  'wsvn.com',
#  'wtae.com',
#  'wthr.com',
#  'wtkr.com',
#  'wtoc.com',
#  'wtvr.com',
#  'wwd.com',
#  'wweek.com',
#  'wwltv.com',
#  'wxii12.com',
#  'xxlmag.com',
#  'yle.fi',
#  'yna.co.kr',
#  'zdnet.com'}

# %%
rated = [(n, float(r.split("/")[0])) for n,r in rated]

# %%
reliable = [k for k in rated if k[1]>=60]
len(reliable)
# Out:
# 328

# %%
unreliable = [k for k in rated if k[1]<60]
len(unreliable)
# Out:
# 13

# %%
unreliable
# Out:
# [('dailykos.com', 37.0),
#  ('sciencetimes.com', 44.5),
#  ('gulfnews.com', 47.0),
#  ('tmz.com', 44.5),
#  ('aawsat.com', 39.5),
#  ('outkick.com', 57.0),
#  ('frontpagemag.com', 22.5),
#  ('redstate.com', 52.0),
#  ('lifesitenews.com', 17.5),
#  ('xinhuanet.com', 7.5),
#  ('trtworld.com', 52.0),
#  ('newsmax.com', 35.0),
#  ('sputniknews.com', 30.0)]

# %%
reliable
# Out:
# [('foxnews.com', 69.5),
#  ('unionleader.com', 100.0),
#  ('axios.com', 100.0),
#  ('news12.com', 90.0),
#  ('democratandchronicle.com', 92.5),
#  ('greenvilleonline.com', 87.5),
#  ('cpr.org', 100.0),
#  ('cnet.com', 100.0),
#  ('healthline.com', 82.5),
#  ('upi.com', 82.5),
#  ('ctvnews.ca', 100.0),
#  ('channel4.com', 95.0),
#  ('ndr.de', 95.0),
#  ('houstonpress.com', 87.5),
#  ('qz.com', 100.0),
#  ('calgary.ctvnews.ca', 100.0),
#  ('thetruthaboutguns.com', 80.0),
#  ('theblaze.com', 69.5),
#  ('azcentral.com', 92.5),
#  ('abc7ny.com', 82.5),
#  ('the-scientist.com', 100.0),
#  ('variety.com', 100.0),
#  ('fox32chicago.com', 87.5),
#  ('jacksonville.com', 100.0),
#  ('nbcwashington.com', 87.5),
#  ('investors.com', 87.5),
#  ('stripes.com', 100.0),
#  ('nymag.com', 82.5),
#  ('newrepublic.com', 92.5),
#  ('boisestatepublicradio.org', 92.5),
#  ('nbcnews.com', 100.0),
#  ('marketwatch.com', 100.0),
#  ('nj1015.com', 92.5),
#  ('sciencebasedmedicine.org', 87.5),
#  ('niemanlab.org', 100.0),
#  ('rightwingwatch.org', 92.5),
#  ('telegram.com', 100.0),
#  ('heise.de', 87.5),
#  ('edweek.org', 100.0),
#  ('nowthisnews.com', 70.0),
#  ('alternet.org', 87.5),
#  ('wjla.com', 90.0),
#  ('federalnewsnetwork.com', 100.0),
#  ('bristolpost.co.uk', 100.0),
#  ('prospect.org', 92.5),
#  ('vancouverisland.ctvnews.ca', 100.0),
#  ('nhregister.com', 100.0),
#  ('defenseone.com', 100.0),
#  ('heraldtribune.com', 92.5),
#  ('mlive.com', 100.0),
#  ('popular.info', 100.0),
#  ('irishnews.com', 87.5),
#  ('king5.com', 90.0),
#  ('espn.com', 92.5),
#  ('focus.de', 92.5),
#  ('commercialappeal.com', 92.5),
#  ('houstonpublicmedia.org', 100.0),
#  ('leafly.com', 67.5),
#  ('sandiegouniontribune.com', 100.0),
#  ('cnn.com', 87.5),
#  ('gpb.org', 87.5),
#  ('rgj.com', 100.0),
#  ('cbs46.com', 95.0),
#  ('ktvu.com', 87.5),
#  ('deadspin.com', 72.5),
#  ('middleeasteye.net', 75.0),
#  ('khou.com', 100.0),
#  ('popsugar.com', 100.0),
#  ('ladbible.com', 82.5),
#  ('lefigaro.fr', 92.5),
#  ('wcvb.com', 100.0),
#  ('inthesetimes.com', 100.0),
#  ('ottawa.ctvnews.ca', 100.0),
#  ('si.com', 82.5),
#  ('roanoke.com', 92.5),
#  ('wpr.org', 92.5),
#  ('cornwalllive.com', 100.0),
#  ('freep.com', 92.5),
#  ('southbendtribune.com', 100.0),
#  ('orf.at', 95.0),
#  ('phys.org', 87.5),
#  ('sun-sentinel.com', 92.5),
#  ('rawstory.com', 87.5),
#  ('vegnews.com', 100.0),
#  ('lancasteronline.com', 100.0),
#  ('greensboro.com', 85.0),
#  ('hbr.org', 100.0),
#  ('mashable.com', 80.0),
#  ('avclub.com', 100.0),
#  ('london.ctvnews.ca', 100.0),
#  ('franceinter.fr', 100.0),
#  ('courier-journal.com', 92.5),
#  ('phillymag.com', 87.5),
#  ('coindesk.com', 100.0),
#  ('phoenixnewtimes.com', 100.0),
#  ('daytondailynews.com', 87.5),
#  ('capitalgazette.com', 92.5),
#  ('kut.org', 92.5),
#  ('airforcetimes.com', 92.5),
#  ('journalnow.com', 92.5),
#  ('abovethelaw.com', 87.5),
#  ('nativenewsonline.net', 92.5),
#  ('harpersbazaar.com', 75.0),
#  ('247sports.com', 87.5),
#  ('adage.com', 100.0),
#  ('inquirer.net', 100.0),
#  ('justthenews.com', 62.0),
#  ('sciencefocus.com', 72.5),
#  ('curbed.com', 100.0),
#  ('komonews.com', 95.0),
#  ('fox9.com', 82.5),
#  ('baltimoresun.com', 92.5),
#  ('washingtonpost.com', 100.0),
#  ('harpers.org', 92.5),
#  ('whyy.org', 92.5),
#  ('cjr.org', 87.5),
#  ('tallahassee.com', 92.5),
#  ('hollywoodlife.com', 69.5),
#  ('sacbee.com', 100.0),
#  ('cbc.ca', 95.0),
#  ('france3-regions.francetvinfo.fr', 95.0),
#  ('providencejournal.com', 100.0),
#  ('gaytimes.co.uk', 70.0),
#  ('app.com', 92.5),
#  ('self.com', 92.5),
#  ('factcheck.org', 100.0),
#  ('rte.ie', 87.5),
#  ('winnipeg.ctvnews.ca', 100.0),
#  ('inquirer.com', 100.0),
#  ('techtimes.com', 75.0),
#  ('aol.com', 82.5),
#  ('militarytimes.com', 92.5),
#  ('newscientist.com', 87.5),
#  ('swissinfo.ch', 100.0),
#  ('mdr.de', 95.0),
#  ('atlantablackstar.com', 87.5),
#  ('scotsman.com', 92.5),
#  ('bild.de', 69.5),
#  ('dazeddigital.com', 75.0),
#  ('golem.de', 100.0),
#  ('cjonline.com', 87.5),
#  ('lohud.com', 92.5),
#  ('grandforksherald.com', 100.0),
#  ('nj.com', 100.0),
#  ('whdh.com', 82.5),
#  ('insideclimatenews.org', 100.0),
#  ('livescience.com', 100.0),
#  ('missoulian.com', 85.0),
#  ('c-span.org', 87.5),
#  ('atlantic.ctvnews.ca', 100.0),
#  ('bigthink.com', 87.5),
#  ('theatlantic.com', 100.0),
#  ('citizen-times.com', 92.5),
#  ('jacobinmag.com', 92.5),
#  ('nbcbayarea.com', 87.5),
#  ('wtop.com', 92.5),
#  ('express.co.uk', 64.5),
#  ('houstonchronicle.com', 100.0),
#  ('expressandstar.com', 100.0),
#  ('cnsnews.com', 62.0),
#  ('adweek.com', 87.5),
#  ('cincinnati.com', 92.5),
#  ('thegrio.com', 100.0),
#  ('queerty.com', 77.5),
#  ('seattletimes.com', 100.0),
#  ('westword.com', 100.0),
#  ('palmbeachpost.com', 92.5),
#  ('crosscut.com', 100.0),
#  ('msnbc.com', 70.0),
#  ('wfaa.com', 95.0),
#  ('quantamagazine.org', 100.0),
#  ('theroot.com', 80.0),
#  ('foxsports.com', 77.5),
#  ('newstatesman.com', 100.0),
#  ('techdirt.com', 90.0),
#  ('indianexpress.com', 90.0),
#  ('centralmaine.com', 100.0),
#  ('foxbusiness.com', 69.5),
#  ('hulldailymail.co.uk', 100.0),
#  ('civileats.com', 100.0),
#  ('unilad.co.uk', 75.0),
#  ('welt.de', 100.0),
#  ('n-tv.de', 87.5),
#  ('seacoastonline.com', 87.5),
#  ('austinchronicle.com', 92.5),
#  ('walesonline.co.uk', 100.0),
#  ('dallasobserver.com', 87.5),
#  ('vulture.com', 100.0),
#  ('newsbusters.org', 92.5),
#  ('barrons.com', 100.0),
#  ('popularmechanics.com', 100.0),
#  ('chicagoreader.com', 80.0),
#  ('sueddeutsche.de', 100.0),
#  ('plantbasednews.org', 100.0),
#  ('journalstar.com', 85.0),
#  ('montgomeryadvertiser.com', 100.0),
#  ('wbez.org', 92.5),
#  ('nationalinterest.org', 92.5),
#  ('jezebel.com', 87.5),
#  ('nejm.org', 100.0),
#  ('nwitimes.com', 85.0),
#  ('christianpost.com', 87.5),
#  ('lmtonline.com', 100.0),
#  ('snopes.com', 95.0),
#  ('fox10phoenix.com', 87.5),
#  ('womenshealthmag.com', 80.0),
#  ('outsideonline.com', 80.0),
#  ('insider.com', 100.0),
#  ('dailyvoice.com', 80.0),
#  ('boingboing.net', 62.0),
#  ('faz.net', 100.0),
#  ('chronicle.com', 100.0),
#  ('spokesman.com', 100.0),
#  ('travelandleisure.com', 75.0),
#  ('nationalpost.com', 100.0),
#  ('entrepreneur.com', 87.5),
#  ('yorkshirepost.co.uk', 87.5),
#  ('bylinetimes.com', 82.5),
#  ('michiganradio.org', 100.0),
#  ('inquisitr.com', 80.0),
#  ('courthousenews.com', 75.0),
#  ('irishcentral.com', 80.0),
#  ('independent.co.uk', 100.0),
#  ('health.com', 82.5),
#  ('thehill.com', 80.0),
#  ('wgbh.org', 92.5),
#  ('insideedition.com', 92.5),
#  ('texasmonthly.com', 95.0),
#  ('rfi.fr', 100.0),
#  ('space.com', 87.5),
#  ('jalopnik.com', 100.0),
#  ('handelsblatt.com', 100.0),
#  ('lifehacker.com', 92.5),
#  ('rnd.de', 92.5),
#  ('politifact.com', 100.0),
#  ('chicagotribune.com', 92.5),
#  ('nbcboston.com', 92.5),
#  ('pennlive.com', 100.0),
#  ('eonline.com', 82.5),
#  ('timesunion.com', 100.0),
#  ('deadline.com', 100.0),
#  ('patheos.com', 64.5),
#  ('atlasobscura.com', 92.5),
#  ('realclearpolitics.com', 80.0),
#  ('billboard.com', 92.5),
#  ('lepoint.fr', 80.0),
#  ('madison.com', 92.5),
#  ('tagesschau.de', 95.0),
#  ('nbcdfw.com', 87.5),
#  ('sciencealert.com', 100.0),
#  ('medpagetoday.com', 87.5),
#  ('indystar.com', 100.0),
#  ('kotaku.com', 92.5),
#  ('lawandcrime.com', 100.0),
#  ('liverpoolecho.co.uk', 100.0),
#  ('thetab.com', 95.0),
#  ('statesman.com', 100.0),
#  ('lcsun-news.com', 92.5),
#  ('fox5dc.com', 87.5),
#  ('thecanary.co', 87.5),
#  ('themoscowtimes.com', 87.5),
#  ('saskatoon.ctvnews.ca', 100.0),
#  ('washingtonblade.com', 87.5),
#  ('merkur.de', 100.0),
#  ('newsweek.com', 100.0),
#  ('reuters.com', 95.0),
#  ('ajc.com', 100.0),
#  ('sfchronicle.com', 100.0),
#  ('montreal.ctvnews.ca', 100.0),
#  ('cbssports.com', 82.5),
#  ('silive.com', 100.0),
#  ('capradio.org', 92.5),
#  ('medicalxpress.com', 87.5),
#  ('q13fox.com', 90.0),
#  ('taz.de', 100.0),
#  ('lemonde.fr', 95.0),
#  ('mediaite.com', 95.0),
#  ('stltoday.com', 85.0),
#  ('pnas.org', 92.5),
#  ('straight.com', 100.0),
#  ('clarionledger.com', 92.5),
#  ('derstandard.at', 100.0),
#  ('birminghammail.co.uk', 100.0),
#  ('tennessean.com', 92.5),
#  ('postandcourier.com', 100.0),
#  ('kitchener.ctvnews.ca', 100.0),
#  ('pix11.com', 87.5),
#  ('duluthnewstribune.com', 100.0),
#  ('12news.com', 100.0),
#  ('knoxnews.com', 92.5),
#  ('dailyrecord.co.uk', 95.0),
#  ('miaminewtimes.com', 87.5),
#  ('vogue.com', 82.5),
#  ('journaltimes.com', 85.0),
#  ('sacurrent.com', 87.5),
#  ('nola.com', 87.5),
#  ('hollywoodreporter.com', 95.0),
#  ('ctpost.com', 100.0),
#  ('texastribune.org', 100.0),
#  ('jsonline.com', 92.5),
#  ('trib.com', 85.0),
#  ('voanews.com', 100.0),
#  ('engadget.com', 100.0),
#  ('scmp.com', 85.0),
#  ('click2houston.com', 100.0),
#  ('chroniclelive.co.uk', 100.0),
#  ('oregonlive.com', 100.0),
#  ('beaconjournal.com', 100.0),
#  ('kcrw.com', 100.0),
#  ('br.de', 100.0),
#  ('ibtimes.com', 70.0),
#  ('standard.co.uk', 75.0),
#  ('nbcphiladelphia.com', 87.5),
#  ('consumerreports.org', 100.0),
#  ('omaha.com', 92.5),
#  ('spiked-online.com', 100.0),
#  ('nbclosangeles.com', 82.5),
#  ('francetvinfo.fr', 95.0),
#  ('11alive.com', 100.0),
#  ('nbcchicago.com', 82.5),
#  ('toronto.ctvnews.ca', 100.0),
#  ('out.com', 87.5),
#  ('csmonitor.com', 100.0),
#  ('cbsnews.com', 95.0),
#  ('kenoshanews.com', 85.0),
#  ('latimes.com', 100.0),
#  ('armytimes.com', 92.5),
#  ('spiegel.de', 100.0)]

# %%
scores = [k[1] for k in rated]

# %%
sns.histplot(scores)
# Out:
# <AxesSubplot:ylabel='Count'>
